# %% [markdown]
# ## COMP5623M Assessment Coursework 1 - Image Classification [100 marks]
#
# The maximum number of marks for each part are shown in the section headers. As indicated in the main heading above, the overall assessment carries a maximum of 100 marks.
#
# This summative assessment is weighted 25% of the final grade for the module.
#
# ### Motivation
#
# Through this coursework, you will:
#
# > 1. Practice building, evaluating, and finetuning a convolutional neural network on an image dataset from development to testing.
# > 2. Gain a deeper understanding of feature maps and filters by visualizing some from a pre-trained network.
#
#
# ### Setup and resources
#
# You must work using this provided template notebook.
#
# Having a GPU will speed up the training process, especially for Question 1.3. See the provided document on Minerva about setting up a working environment for various ways to access a GPU.
#
# Please implement the coursework using **Python and PyTorch**, and refer to the notebooks and exercises provided.
#
# This coursework will use a subset of images from Tiny ImageNet, which is a subset of the ImageNet dataset [https://image-net.org/]. Our subset of Tiny ImageNet contains 30 different categories, we will refer to it as TinyImageNet30. The training set has 450 resized images (64x64 pixels) for each category (13,500 images in total). You can download the training and test set from the Kaggle website:
#
# >[Private class Kaggle competition and data](https://www.kaggle.com/t/9b703e0d71824a658e186d5f69960e27)
#
# To access the dataset, you will need an account on the Kaggle website. Even if you have an existing Kaggle account, please carefully adhere to these instructions, or we may not be able to locate your entries:
#
# > 1. Use your **university email** to register a new account.
# > 2. Set your **Kaggle account NAME** to your university username, for example, ``sc15jb``.
#
# The class Kaggle competition also includes a blind test set, which will be used in Question 1 for evaluating your custom model's performance on a test set. The competition website will compute the test set accuracy, as well as position your model on the class leaderboard.
#
# ### Submission
#
# Please submit the following:
#
# > 1. Your completed Jupyter notebook file, without removing anything in the template, in **.ipynb format.**
# > 2. The **.html version** of your notebook; File > Download as > HTML (.html). Check that all cells have been run and all outputs (including all graphs you would like to be marked) displayed in the .html for marking.
# > 3. Your selected image from section 2.4.2 "Failure analysis"
#
# Final note:
#
# > **Please display everything that you would like to be marked. Under each section, put the relevant code containing your solution. You may re-use functions you defined previously, but any new code must be in the relevant section.** Feel free to add as many code cells as you need under each section.
#
# Your student username (for example, ```sc15jb```):

# %% [markdown]
# sc21vp

# %% [markdown]
# Your full name:

# %% [markdown]
# Vidyasagar Ponnam

# %% [markdown]
# ## Imports
#
# Feel free to add to this section as needed.
#
# You may need to download `cv2` using [pip](https://pypi.org/project/opencv-python/) or [conda](https://anaconda.org/conda-forge/opencv).

# %%
import cv2
import math
import csv
import numpy as np
import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms
from torch.hub import load_state_dict_from_url

from PIL import Image
import matplotlib.pyplot as plt

# replace with your own root directory
root="./data"

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ## QUESTION 1 [55 marks]
#
# One challenge of building a deep learning model is to choose an architecture that can learn the features in the dataset without being unnecessarily complex. The first part of the coursework involves building a CNN and training it on TinyImageNet30.
#
# ### **Overview:**
# *   **1.1.1** PyTorch ```Dataset``` and ```DataLoader``` classes
# *   **1.1.2** PyTorch ```Model``` class for simple CNN model
# *   **1.1.3** Overfitting on a single batch
# *   **1.2.1** Training on complete dataset
# *   **1.2.2** Fine-tuning model
# *   **1.2.3** Generating confusion matrices
# *   **1.3**   Testing on test set on Kaggle
#
#
# ## 1.1 Single-batch training [14 marks]
#
# We will use a method of development called “single-batch training”, or "overfitting a single batch", in which we check that our model and the training code is working properly and can overfit a single training batch (i.e., we can drive the training loss to zero). Then we move on to training on the complete training set and adjust for any overfitting and fine-tune the model via regularisation.
#
# ### 1.1.1 Dataset class [3 marks]
#
# Write a PyTorch ```Dataset``` class (an example [here](https://www.askpython.com/python-modules/pytorch-custom-datasets) for reference) which loads the TinyImage30 dataset and ```DataLoaders``` for training and validation sets.

# %%
import os
import numpy as np
import torch
import torchvision
from torch.utils.data import Dataset
from natsort import natsorted
from torchvision import datasets, transforms
from PIL import Image
import matplotlib.pyplot as plt
from torch import nn, optim

# %%
# Define your own class LoadFromFolder this is for laoding test data set
class LoadFromFolder(Dataset):
    def __init__(self, main_dir, transform):
         
        # Set the loading directory
        self.main_dir =main_dir
        self.transform = transform
         
        # List all images in folder and count them
        all_imgs = os.listdir(main_dir)
        self.total_imgs = natsorted(all_imgs)

    def __len__(self):
    # Return the previously computed number of images
        return len(self.total_imgs)
    def __getitem__(self, idx):
        img_loc = os.path.join(self.main_dir, self.total_imgs[idx])
    # Use PIL for image loading
        image = Image.open(img_loc).convert("RGB")
    # Apply the transformations
        tensor_image = self.transform(image)
     
        return self.total_imgs[idx] ,torch.unsqueeze(tensor_image, 0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11240/1408506528.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
#checking for device
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
from torchvision.datasets import ImageFolder
trnsfrm = transforms.Compose([
    transforms.ToTensor()
])

dataset = ImageFolder(root+'/train_set/train_set/',transform=trnsfrm)
print(len(dataset.classes))
train_size = int(0.8 * len(dataset))
validation_size = len(dataset) - train_size
train_dataset, validation_dataset = torch.utils.data.random_split(dataset, [train_size, validation_size])## spliting train_set for both train_dataset and validation_set.
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset,batch_size=15, shuffle=True)
#train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=True)
#testset = LoadFromFolder(main_dir="/content/drive/MyDrive/test_set", transform= transforms.ToTensor())
#dataloader =torch.utils.data.DataLoader(testset,batch_size=10, shuffle=True)
#print(next(iter(dataloader)).shape)
# Out:
# 30

# %%
#mycode
#Transforms
transform=transforms.Compose([
    #transforms.Grayscale(num_output_channels = 1),
    #transforms.Resize((150,150)),
    #transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5,0.5,0.5], # 0-1 to [-1,1] , formula (x-mean)/std
                        [0.5,0.5,0.5])
])

batch_size = 4
learning_rate = 0.001



# Loading datasets
train_dataset = datasets.ImageFolder(root+'/train_set/train_set/', 
                                     transform = transform)
validation_dataset = datasets.ImageFolder(root+'/test_set/',
                                    transform = transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                          shuffle=True)

validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=batch_size,
                                         shuffle=False)

# %% [markdown]
# ### 1.1.2 Define a CNN model [3 marks]
#
# Create a new model class using a combination of convolutional and fully connected layers, ReLU, and max-pool.

# %%
net = nn.Sequential(
    nn.Conv2d(in_channels=3,out_channels=8, kernel_size=3,padding=1),    # no padding, stride=1, dilation=1 by default
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=2, stride=2),
    nn.Conv2d(in_channels=8,out_channels=16,  kernel_size=3,padding=1),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=2, stride=2),
    nn.Conv2d(in_channels=16,out_channels=32,  kernel_size=3,padding=1),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=2, stride=2),
    nn.Flatten(),
    nn.Linear(32*8*8,128),     # with 32x32 input, the feature map size reduces to 8x8 with 16 channels.
    nn.ReLU(),
    nn.Linear(128,30)
)

net = net.to(device)

for param in net.parameters():
    print(param.shape)
# Out:
# torch.Size([8, 3, 3, 3])
# torch.Size([8])
# torch.Size([16, 8, 3, 3])
# torch.Size([16])
# torch.Size([32, 16, 3, 3])
# torch.Size([32])
# torch.Size([128, 2048])
# torch.Size([128])
# torch.Size([30, 128])
# torch.Size([30])

# %% [markdown]
# ### 1.1.3 Single-batch training [8 marks]
#
# Write the foundational code which trains your network given **one single batch** of training data and computes the loss on the complete validation set for each epoch. Set ```batch_size = 64```.
#
# Display the graph of the training and validation loss over training epochs, showing as long as necessary to show you can drive the training loss to zero.
#
# > Please leave all graphs and code you would like to be marked clearly displayed without needing to run code cells or wait for training.

# %%
def stats(loader, net):
    correct = 0
    total = 0
    running_loss = 0
    n = 0    # counter for number of minibatches
    with torch.no_grad():
        for data in loader:
            image_s , label_s = data
            images, labels = image_s.to(device), label_s.to(device)
            outputs = net(images)      
            
            # accumulate loss
            running_loss += loss_fn(outputs, labels)
            n += 1
            
            # accumulate data for accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)    # add in the number of labels in this minibatch
            correct += (predicted == labels).sum().item()  # add in the number of correct labels
            
    return running_loss/n, correct/total

# %%
# %%time
#shivam code
nepochs = 1000
statsrec = np.zeros((4,nepochs))
results_path1 = root+'/results/001.pt'

# single-batch
it = iter(train_loader)
input_s, label_s = next(it)
inputs, labels = input_s.to(device), label_s.to(device)

# training
for epoch in range(nepochs):  # loop over the dataset multiple times
    correct = 0          # number of examples predicted correctly (for accuracy)
    total = 0            # number of examples
    running_loss = 0.0   # accumulated loss (for mean loss)
    n = 0                # number of minibatches


    # Zero the parameter gradients
    optimizer.zero_grad()

    # Forward, backward, and update parameters
    outputs = net(inputs)
    loss = loss_fn(outputs, labels)
    loss.backward()
    optimizer.step()

    # accumulate loss
    running_loss += loss.item()
    n += 1

    # accumulate data for accuracy
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)    # add in the number of labels in this minibatch
    correct += (predicted == labels).sum().item()  # add in the number of correct labels

    # collect together statistics for this epoch
    ltrn = running_loss/n
    atrn = correct/total 
    ltst, atst = stats(validation_loader, net)

    statsrec[:,epoch] = (ltrn, atrn, ltst.cpu(), atst)
    print(f"epoch: {epoch} training loss: {ltrn: .3f} training accuracy: {atrn: .1%}  test loss: {ltst: .3f} test accuracy: {atst: .1%}")
    #for i in range(30):
        #acc = 100.0 * correct[i] / total[i]
       # print(f'Accuracy of {classes[i]}: {acc} %')
# save network parameters, losses and accuracy
torch.save({"state_dict": net.state_dict(), "stats": statsrec}, results_path1)
# Out:
# epoch: 0 training loss:  3.406 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 1 training loss:  3.406 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 2 training loss:  3.406 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 3 training loss:  3.406 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 4 training loss:  3.406 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 5 training loss:  3.406 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 6 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 7 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 8 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 9 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 10 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 11 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 12 training loss:  3.405 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 13 training loss:  3.404 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 14 training loss:  3.404 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 15 training loss:  3.404 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 16 training loss:  3.404 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 17 training loss:  3.404 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 18 training loss:  3.403 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 19 training loss:  3.403 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 20 training loss:  3.403 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 21 training loss:  3.403 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 22 training loss:  3.403 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 23 training loss:  3.402 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 24 training loss:  3.402 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 25 training loss:  3.402 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 26 training loss:  3.402 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 27 training loss:  3.402 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 28 training loss:  3.401 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 29 training loss:  3.401 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 30 training loss:  3.401 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 31 training loss:  3.401 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 32 training loss:  3.400 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 33 training loss:  3.400 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 34 training loss:  3.400 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 35 training loss:  3.400 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 36 training loss:  3.400 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 37 training loss:  3.399 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 38 training loss:  3.399 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 39 training loss:  3.399 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 40 training loss:  3.399 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 41 training loss:  3.398 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 42 training loss:  3.398 training accuracy:  1.6%  test loss:  3.403 test accuracy:  3.3%
# epoch: 43 training loss:  3.398 training accuracy:  3.1%  test loss:  3.403 test accuracy:  3.4%
# epoch: 44 training loss:  3.398 training accuracy:  3.1%  test loss:  3.403 test accuracy:  3.4%
# epoch: 45 training loss:  3.398 training accuracy:  3.1%  test loss:  3.403 test accuracy:  3.5%
# epoch: 46 training loss:  3.397 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 47 training loss:  3.397 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.8%
# epoch: 48 training loss:  3.397 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.9%
# epoch: 49 training loss:  3.397 training accuracy:  6.2%  test loss:  3.403 test accuracy:  4.2%
# epoch: 50 training loss:  3.396 training accuracy:  6.2%  test loss:  3.403 test accuracy:  4.3%
# epoch: 51 training loss:  3.396 training accuracy:  6.2%  test loss:  3.403 test accuracy:  4.6%
# epoch: 52 training loss:  3.396 training accuracy:  6.2%  test loss:  3.402 test accuracy:  4.9%
# epoch: 53 training loss:  3.396 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.1%
# epoch: 54 training loss:  3.396 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.3%
# epoch: 55 training loss:  3.395 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.2%
# epoch: 56 training loss:  3.395 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.4%
# epoch: 57 training loss:  3.395 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.5%
# epoch: 58 training loss:  3.395 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.6%
# epoch: 59 training loss:  3.394 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.3%
# epoch: 60 training loss:  3.394 training accuracy:  6.2%  test loss:  3.402 test accuracy:  5.1%
# epoch: 61 training loss:  3.394 training accuracy:  6.2%  test loss:  3.402 test accuracy:  4.8%
# epoch: 62 training loss:  3.394 training accuracy:  6.2%  test loss:  3.402 test accuracy:  4.5%
# epoch: 63 training loss:  3.393 training accuracy:  6.2%  test loss:  3.402 test accuracy:  4.1%
# epoch: 64 training loss:  3.393 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.9%
# epoch: 65 training loss:  3.393 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.6%
# epoch: 66 training loss:  3.393 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.6%
# epoch: 67 training loss:  3.393 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.6%
# epoch: 68 training loss:  3.392 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.6%
# epoch: 69 training loss:  3.392 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.6%
# epoch: 70 training loss:  3.392 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 71 training loss:  3.392 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 72 training loss:  3.391 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 73 training loss:  3.391 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 74 training loss:  3.391 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 75 training loss:  3.391 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 76 training loss:  3.390 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 77 training loss:  3.390 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 78 training loss:  3.390 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 79 training loss:  3.390 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 80 training loss:  3.389 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 81 training loss:  3.389 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 82 training loss:  3.389 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 83 training loss:  3.389 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 84 training loss:  3.388 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 85 training loss:  3.388 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 86 training loss:  3.388 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 87 training loss:  3.388 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 88 training loss:  3.388 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 89 training loss:  3.387 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 90 training loss:  3.387 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 91 training loss:  3.387 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 92 training loss:  3.387 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 93 training loss:  3.386 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 94 training loss:  3.386 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 95 training loss:  3.386 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 96 training loss:  3.386 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 97 training loss:  3.385 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 98 training loss:  3.385 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 99 training loss:  3.385 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 100 training loss:  3.385 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 101 training loss:  3.384 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 102 training loss:  3.384 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 103 training loss:  3.384 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 104 training loss:  3.383 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 105 training loss:  3.383 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 106 training loss:  3.383 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 107 training loss:  3.383 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 108 training loss:  3.382 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 109 training loss:  3.382 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 110 training loss:  3.382 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 111 training loss:  3.382 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 112 training loss:  3.381 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 113 training loss:  3.381 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 114 training loss:  3.381 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 115 training loss:  3.381 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 116 training loss:  3.380 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 117 training loss:  3.380 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 118 training loss:  3.380 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 119 training loss:  3.380 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 120 training loss:  3.379 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 121 training loss:  3.379 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 122 training loss:  3.379 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 123 training loss:  3.378 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 124 training loss:  3.378 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 125 training loss:  3.378 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 126 training loss:  3.378 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 127 training loss:  3.377 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 128 training loss:  3.377 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 129 training loss:  3.377 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 130 training loss:  3.377 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 131 training loss:  3.376 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 132 training loss:  3.376 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 133 training loss:  3.376 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 134 training loss:  3.375 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 135 training loss:  3.375 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 136 training loss:  3.375 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 137 training loss:  3.374 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 138 training loss:  3.374 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 139 training loss:  3.374 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 140 training loss:  3.374 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 141 training loss:  3.373 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 142 training loss:  3.373 training accuracy:  6.2%  test loss:  3.402 test accuracy:  3.5%
# epoch: 143 training loss:  3.373 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 144 training loss:  3.372 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 145 training loss:  3.372 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 146 training loss:  3.372 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 147 training loss:  3.371 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 148 training loss:  3.371 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 149 training loss:  3.371 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 150 training loss:  3.370 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 151 training loss:  3.370 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 152 training loss:  3.370 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 153 training loss:  3.369 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 154 training loss:  3.369 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 155 training loss:  3.369 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 156 training loss:  3.368 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 157 training loss:  3.368 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 158 training loss:  3.368 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 159 training loss:  3.367 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 160 training loss:  3.367 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 161 training loss:  3.367 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 162 training loss:  3.366 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 163 training loss:  3.366 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 164 training loss:  3.366 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 165 training loss:  3.365 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 166 training loss:  3.365 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 167 training loss:  3.365 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 168 training loss:  3.364 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 169 training loss:  3.364 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 170 training loss:  3.364 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 171 training loss:  3.363 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 172 training loss:  3.363 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 173 training loss:  3.362 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 174 training loss:  3.362 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.5%
# epoch: 175 training loss:  3.362 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 176 training loss:  3.361 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 177 training loss:  3.361 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 178 training loss:  3.360 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 179 training loss:  3.360 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 180 training loss:  3.360 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 181 training loss:  3.359 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 182 training loss:  3.359 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 183 training loss:  3.358 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 184 training loss:  3.358 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.6%
# epoch: 185 training loss:  3.357 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.7%
# epoch: 186 training loss:  3.357 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.7%
# epoch: 187 training loss:  3.357 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.7%
# epoch: 188 training loss:  3.356 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.7%
# epoch: 189 training loss:  3.356 training accuracy:  6.2%  test loss:  3.403 test accuracy:  3.9%
# epoch: 190 training loss:  3.355 training accuracy:  7.8%  test loss:  3.403 test accuracy:  3.9%
# epoch: 191 training loss:  3.355 training accuracy:  7.8%  test loss:  3.403 test accuracy:  3.9%
# epoch: 192 training loss:  3.354 training accuracy:  7.8%  test loss:  3.403 test accuracy:  3.9%
# epoch: 193 training loss:  3.354 training accuracy:  7.8%  test loss:  3.403 test accuracy:  4.0%
# epoch: 194 training loss:  3.353 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.0%
# epoch: 195 training loss:  3.353 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.0%
# epoch: 196 training loss:  3.352 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.0%
# epoch: 197 training loss:  3.352 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.1%
# epoch: 198 training loss:  3.351 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.1%
# epoch: 199 training loss:  3.351 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.1%
# epoch: 200 training loss:  3.350 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.2%
# epoch: 201 training loss:  3.350 training accuracy:  7.8%  test loss:  3.404 test accuracy:  4.2%
# epoch: 202 training loss:  3.349 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.4%
# epoch: 203 training loss:  3.349 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.5%
# epoch: 204 training loss:  3.348 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.5%
# epoch: 205 training loss:  3.348 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.6%
# epoch: 206 training loss:  3.347 training accuracy:  9.4%  test loss:  3.404 test accuracy:  4.6%
# epoch: 207 training loss:  3.347 training accuracy:  9.4%  test loss:  3.404 test accuracy:  4.5%
# epoch: 208 training loss:  3.346 training accuracy:  9.4%  test loss:  3.404 test accuracy:  4.6%
# epoch: 209 training loss:  3.346 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.6%
# epoch: 210 training loss:  3.345 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.7%
# epoch: 211 training loss:  3.344 training accuracy:  10.9%  test loss:  3.404 test accuracy:  4.7%
# epoch: 212 training loss:  3.344 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.5%
# epoch: 213 training loss:  3.343 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.4%
# epoch: 214 training loss:  3.343 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.5%
# epoch: 215 training loss:  3.342 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.4%
# epoch: 216 training loss:  3.341 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.3%
# epoch: 217 training loss:  3.341 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.2%
# epoch: 218 training loss:  3.340 training accuracy:  9.4%  test loss:  3.405 test accuracy:  4.1%
# epoch: 219 training loss:  3.339 training accuracy:  9.4%  test loss:  3.405 test accuracy:  3.9%
# epoch: 220 training loss:  3.339 training accuracy:  9.4%  test loss:  3.405 test accuracy:  3.8%
# epoch: 221 training loss:  3.338 training accuracy:  9.4%  test loss:  3.405 test accuracy:  3.6%
# epoch: 222 training loss:  3.337 training accuracy:  7.8%  test loss:  3.405 test accuracy:  3.6%
# epoch: 223 training loss:  3.337 training accuracy:  7.8%  test loss:  3.405 test accuracy:  3.6%
# epoch: 224 training loss:  3.336 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 225 training loss:  3.335 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 226 training loss:  3.334 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 227 training loss:  3.334 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 228 training loss:  3.333 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 229 training loss:  3.332 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 230 training loss:  3.331 training accuracy:  7.8%  test loss:  3.406 test accuracy:  3.5%
# epoch: 231 training loss:  3.331 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 232 training loss:  3.330 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 233 training loss:  3.329 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 234 training loss:  3.328 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 235 training loss:  3.327 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 236 training loss:  3.327 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 237 training loss:  3.326 training accuracy:  7.8%  test loss:  3.407 test accuracy:  3.5%
# epoch: 238 training loss:  3.325 training accuracy:  7.8%  test loss:  3.408 test accuracy:  3.5%
# epoch: 239 training loss:  3.324 training accuracy:  7.8%  test loss:  3.408 test accuracy:  3.5%
# epoch: 240 training loss:  3.323 training accuracy:  6.2%  test loss:  3.408 test accuracy:  3.5%
# epoch: 241 training loss:  3.322 training accuracy:  6.2%  test loss:  3.408 test accuracy:  3.5%
# epoch: 242 training loss:  3.321 training accuracy:  6.2%  test loss:  3.409 test accuracy:  3.5%
# epoch: 243 training loss:  3.320 training accuracy:  6.2%  test loss:  3.409 test accuracy:  3.5%
# epoch: 244 training loss:  3.319 training accuracy:  6.2%  test loss:  3.409 test accuracy:  3.5%
# epoch: 245 training loss:  3.318 training accuracy:  6.2%  test loss:  3.409 test accuracy:  3.5%
# epoch: 246 training loss:  3.317 training accuracy:  6.2%  test loss:  3.409 test accuracy:  3.5%
# epoch: 247 training loss:  3.316 training accuracy:  6.2%  test loss:  3.410 test accuracy:  3.5%
# epoch: 248 training loss:  3.315 training accuracy:  6.2%  test loss:  3.410 test accuracy:  3.5%
# epoch: 249 training loss:  3.314 training accuracy:  6.2%  test loss:  3.410 test accuracy:  3.5%
# epoch: 250 training loss:  3.313 training accuracy:  6.2%  test loss:  3.411 test accuracy:  3.5%
# epoch: 251 training loss:  3.312 training accuracy:  6.2%  test loss:  3.411 test accuracy:  3.5%
# epoch: 252 training loss:  3.311 training accuracy:  6.2%  test loss:  3.411 test accuracy:  3.5%
# epoch: 253 training loss:  3.310 training accuracy:  6.2%  test loss:  3.412 test accuracy:  3.5%
# epoch: 254 training loss:  3.309 training accuracy:  6.2%  test loss:  3.412 test accuracy:  3.5%
# epoch: 255 training loss:  3.307 training accuracy:  6.2%  test loss:  3.412 test accuracy:  3.5%
# epoch: 256 training loss:  3.306 training accuracy:  6.2%  test loss:  3.413 test accuracy:  3.5%
# epoch: 257 training loss:  3.305 training accuracy:  6.2%  test loss:  3.413 test accuracy:  3.5%
# epoch: 258 training loss:  3.304 training accuracy:  6.2%  test loss:  3.414 test accuracy:  3.5%
# epoch: 259 training loss:  3.302 training accuracy:  6.2%  test loss:  3.414 test accuracy:  3.5%
# epoch: 260 training loss:  3.301 training accuracy:  6.2%  test loss:  3.414 test accuracy:  3.5%
# epoch: 261 training loss:  3.300 training accuracy:  6.2%  test loss:  3.415 test accuracy:  3.5%
# epoch: 262 training loss:  3.299 training accuracy:  6.2%  test loss:  3.415 test accuracy:  3.5%
# epoch: 263 training loss:  3.297 training accuracy:  6.2%  test loss:  3.416 test accuracy:  3.5%
# epoch: 264 training loss:  3.296 training accuracy:  6.2%  test loss:  3.417 test accuracy:  3.5%
# epoch: 265 training loss:  3.295 training accuracy:  6.2%  test loss:  3.417 test accuracy:  3.5%
# epoch: 266 training loss:  3.293 training accuracy:  6.2%  test loss:  3.418 test accuracy:  3.5%
# epoch: 267 training loss:  3.292 training accuracy:  6.2%  test loss:  3.418 test accuracy:  3.5%
# epoch: 268 training loss:  3.290 training accuracy:  6.2%  test loss:  3.419 test accuracy:  3.5%
# epoch: 269 training loss:  3.289 training accuracy:  6.2%  test loss:  3.420 test accuracy:  3.5%
# epoch: 270 training loss:  3.287 training accuracy:  6.2%  test loss:  3.420 test accuracy:  3.5%
# epoch: 271 training loss:  3.286 training accuracy:  6.2%  test loss:  3.421 test accuracy:  3.5%
# epoch: 272 training loss:  3.284 training accuracy:  6.2%  test loss:  3.422 test accuracy:  3.5%
# epoch: 273 training loss:  3.283 training accuracy:  6.2%  test loss:  3.423 test accuracy:  3.5%
# epoch: 274 training loss:  3.281 training accuracy:  6.2%  test loss:  3.424 test accuracy:  3.5%
# epoch: 275 training loss:  3.279 training accuracy:  6.2%  test loss:  3.424 test accuracy:  3.5%
# epoch: 276 training loss:  3.278 training accuracy:  6.2%  test loss:  3.425 test accuracy:  3.5%
# epoch: 277 training loss:  3.276 training accuracy:  6.2%  test loss:  3.426 test accuracy:  3.5%
# epoch: 278 training loss:  3.274 training accuracy:  6.2%  test loss:  3.427 test accuracy:  3.5%
# epoch: 279 training loss:  3.273 training accuracy:  6.2%  test loss:  3.428 test accuracy:  3.5%
# epoch: 280 training loss:  3.271 training accuracy:  6.2%  test loss:  3.429 test accuracy:  3.5%
# epoch: 281 training loss:  3.269 training accuracy:  6.2%  test loss:  3.431 test accuracy:  3.5%
# epoch: 282 training loss:  3.268 training accuracy:  6.2%  test loss:  3.432 test accuracy:  3.5%
# epoch: 283 training loss:  3.266 training accuracy:  6.2%  test loss:  3.433 test accuracy:  3.5%
# epoch: 284 training loss:  3.264 training accuracy:  6.2%  test loss:  3.434 test accuracy:  3.5%
# epoch: 285 training loss:  3.262 training accuracy:  6.2%  test loss:  3.436 test accuracy:  3.5%
# epoch: 286 training loss:  3.260 training accuracy:  6.2%  test loss:  3.437 test accuracy:  3.5%
# epoch: 287 training loss:  3.259 training accuracy:  6.2%  test loss:  3.439 test accuracy:  3.5%
# epoch: 288 training loss:  3.257 training accuracy:  6.2%  test loss:  3.440 test accuracy:  3.5%
# epoch: 289 training loss:  3.255 training accuracy:  6.2%  test loss:  3.442 test accuracy:  3.5%
# epoch: 290 training loss:  3.253 training accuracy:  6.2%  test loss:  3.444 test accuracy:  3.5%
# epoch: 291 training loss:  3.251 training accuracy:  6.2%  test loss:  3.445 test accuracy:  3.5%
# epoch: 292 training loss:  3.249 training accuracy:  6.2%  test loss:  3.447 test accuracy:  3.5%
# epoch: 293 training loss:  3.248 training accuracy:  6.2%  test loss:  3.449 test accuracy:  3.5%
# epoch: 294 training loss:  3.246 training accuracy:  6.2%  test loss:  3.451 test accuracy:  3.5%
# epoch: 295 training loss:  3.244 training accuracy:  6.2%  test loss:  3.453 test accuracy:  3.5%
# epoch: 296 training loss:  3.242 training accuracy:  6.2%  test loss:  3.455 test accuracy:  3.5%
# epoch: 297 training loss:  3.240 training accuracy:  6.2%  test loss:  3.457 test accuracy:  3.5%
# epoch: 298 training loss:  3.238 training accuracy:  6.2%  test loss:  3.459 test accuracy:  3.7%
# epoch: 299 training loss:  3.236 training accuracy:  7.8%  test loss:  3.462 test accuracy:  3.7%
# epoch: 300 training loss:  3.235 training accuracy:  7.8%  test loss:  3.464 test accuracy:  3.7%
# epoch: 301 training loss:  3.233 training accuracy:  7.8%  test loss:  3.467 test accuracy:  3.9%
# epoch: 302 training loss:  3.231 training accuracy:  7.8%  test loss:  3.469 test accuracy:  3.9%
# epoch: 303 training loss:  3.229 training accuracy:  9.4%  test loss:  3.472 test accuracy:  3.9%
# epoch: 304 training loss:  3.227 training accuracy:  7.8%  test loss:  3.474 test accuracy:  3.9%
# epoch: 305 training loss:  3.226 training accuracy:  9.4%  test loss:  3.477 test accuracy:  3.8%
# epoch: 306 training loss:  3.224 training accuracy:  9.4%  test loss:  3.480 test accuracy:  3.6%
# epoch: 307 training loss:  3.222 training accuracy:  9.4%  test loss:  3.483 test accuracy:  3.3%
# epoch: 308 training loss:  3.221 training accuracy:  9.4%  test loss:  3.486 test accuracy:  3.4%
# epoch: 309 training loss:  3.219 training accuracy:  9.4%  test loss:  3.489 test accuracy:  3.3%
# epoch: 310 training loss:  3.217 training accuracy:  9.4%  test loss:  3.492 test accuracy:  3.3%
# epoch: 311 training loss:  3.216 training accuracy:  9.4%  test loss:  3.495 test accuracy:  3.2%
# epoch: 312 training loss:  3.214 training accuracy:  9.4%  test loss:  3.498 test accuracy:  3.3%
# epoch: 313 training loss:  3.213 training accuracy:  9.4%  test loss:  3.501 test accuracy:  3.4%
# epoch: 314 training loss:  3.211 training accuracy:  9.4%  test loss:  3.505 test accuracy:  3.3%
# epoch: 315 training loss:  3.210 training accuracy:  7.8%  test loss:  3.508 test accuracy:  3.3%
# epoch: 316 training loss:  3.208 training accuracy:  7.8%  test loss:  3.511 test accuracy:  3.3%
# epoch: 317 training loss:  3.207 training accuracy:  7.8%  test loss:  3.514 test accuracy:  3.1%
# epoch: 318 training loss:  3.206 training accuracy:  7.8%  test loss:  3.517 test accuracy:  3.2%
# epoch: 319 training loss:  3.204 training accuracy:  7.8%  test loss:  3.521 test accuracy:  3.2%
# epoch: 320 training loss:  3.203 training accuracy:  7.8%  test loss:  3.524 test accuracy:  3.3%
# epoch: 321 training loss:  3.202 training accuracy:  7.8%  test loss:  3.527 test accuracy:  3.3%
# epoch: 322 training loss:  3.201 training accuracy:  7.8%  test loss:  3.530 test accuracy:  3.3%
# epoch: 323 training loss:  3.199 training accuracy:  7.8%  test loss:  3.533 test accuracy:  3.3%
# epoch: 324 training loss:  3.198 training accuracy:  7.8%  test loss:  3.536 test accuracy:  3.3%
# epoch: 325 training loss:  3.197 training accuracy:  7.8%  test loss:  3.539 test accuracy:  3.3%
# epoch: 326 training loss:  3.196 training accuracy:  7.8%  test loss:  3.542 test accuracy:  3.3%
# epoch: 327 training loss:  3.195 training accuracy:  7.8%  test loss:  3.545 test accuracy:  3.2%
# epoch: 328 training loss:  3.194 training accuracy:  7.8%  test loss:  3.548 test accuracy:  3.3%
# epoch: 329 training loss:  3.193 training accuracy:  7.8%  test loss:  3.551 test accuracy:  3.3%
# epoch: 330 training loss:  3.192 training accuracy:  7.8%  test loss:  3.553 test accuracy:  3.3%
# epoch: 331 training loss:  3.191 training accuracy:  7.8%  test loss:  3.556 test accuracy:  3.3%
# epoch: 332 training loss:  3.189 training accuracy:  7.8%  test loss:  3.558 test accuracy:  3.3%
# epoch: 333 training loss:  3.188 training accuracy:  7.8%  test loss:  3.561 test accuracy:  3.3%
# epoch: 334 training loss:  3.187 training accuracy:  7.8%  test loss:  3.563 test accuracy:  3.3%
# epoch: 335 training loss:  3.186 training accuracy:  7.8%  test loss:  3.566 test accuracy:  3.3%
# epoch: 336 training loss:  3.185 training accuracy:  7.8%  test loss:  3.568 test accuracy:  3.3%
# epoch: 337 training loss:  3.184 training accuracy:  7.8%  test loss:  3.570 test accuracy:  3.3%
# epoch: 338 training loss:  3.183 training accuracy:  7.8%  test loss:  3.572 test accuracy:  3.3%
# epoch: 339 training loss:  3.182 training accuracy:  7.8%  test loss:  3.574 test accuracy:  3.3%
# epoch: 340 training loss:  3.181 training accuracy:  7.8%  test loss:  3.576 test accuracy:  3.3%
# epoch: 341 training loss:  3.181 training accuracy:  7.8%  test loss:  3.577 test accuracy:  3.3%
# epoch: 342 training loss:  3.180 training accuracy:  7.8%  test loss:  3.579 test accuracy:  3.3%
# epoch: 343 training loss:  3.179 training accuracy:  7.8%  test loss:  3.581 test accuracy:  3.3%
# epoch: 344 training loss:  3.178 training accuracy:  7.8%  test loss:  3.582 test accuracy:  3.3%
# epoch: 345 training loss:  3.177 training accuracy:  7.8%  test loss:  3.584 test accuracy:  3.3%
# epoch: 346 training loss:  3.176 training accuracy:  7.8%  test loss:  3.586 test accuracy:  3.3%
# epoch: 347 training loss:  3.175 training accuracy:  7.8%  test loss:  3.587 test accuracy:  3.3%
# epoch: 348 training loss:  3.174 training accuracy:  7.8%  test loss:  3.589 test accuracy:  3.3%
# epoch: 349 training loss:  3.173 training accuracy:  7.8%  test loss:  3.590 test accuracy:  3.3%
# epoch: 350 training loss:  3.172 training accuracy:  7.8%  test loss:  3.591 test accuracy:  3.3%
# epoch: 351 training loss:  3.171 training accuracy:  7.8%  test loss:  3.593 test accuracy:  3.3%
# epoch: 352 training loss:  3.170 training accuracy:  7.8%  test loss:  3.594 test accuracy:  3.3%
# epoch: 353 training loss:  3.169 training accuracy:  7.8%  test loss:  3.595 test accuracy:  3.3%
# epoch: 354 training loss:  3.169 training accuracy:  7.8%  test loss:  3.597 test accuracy:  3.3%
# epoch: 355 training loss:  3.168 training accuracy:  7.8%  test loss:  3.598 test accuracy:  3.3%
# epoch: 356 training loss:  3.167 training accuracy:  7.8%  test loss:  3.599 test accuracy:  3.3%
# epoch: 357 training loss:  3.166 training accuracy:  7.8%  test loss:  3.601 test accuracy:  3.3%
# epoch: 358 training loss:  3.165 training accuracy:  7.8%  test loss:  3.602 test accuracy:  3.3%
# epoch: 359 training loss:  3.164 training accuracy:  7.8%  test loss:  3.603 test accuracy:  3.3%
# epoch: 360 training loss:  3.164 training accuracy:  7.8%  test loss:  3.605 test accuracy:  3.3%
# epoch: 361 training loss:  3.163 training accuracy:  7.8%  test loss:  3.606 test accuracy:  3.3%
# epoch: 362 training loss:  3.162 training accuracy:  7.8%  test loss:  3.608 test accuracy:  3.3%
# epoch: 363 training loss:  3.161 training accuracy:  7.8%  test loss:  3.609 test accuracy:  3.3%
# epoch: 364 training loss:  3.160 training accuracy:  7.8%  test loss:  3.610 test accuracy:  3.3%
# epoch: 365 training loss:  3.160 training accuracy:  7.8%  test loss:  3.612 test accuracy:  3.3%
# epoch: 366 training loss:  3.159 training accuracy:  7.8%  test loss:  3.613 test accuracy:  3.3%
# epoch: 367 training loss:  3.158 training accuracy:  7.8%  test loss:  3.614 test accuracy:  3.3%
# epoch: 368 training loss:  3.157 training accuracy:  7.8%  test loss:  3.616 test accuracy:  3.3%
# epoch: 369 training loss:  3.156 training accuracy:  7.8%  test loss:  3.617 test accuracy:  3.3%
# epoch: 370 training loss:  3.156 training accuracy:  7.8%  test loss:  3.619 test accuracy:  3.3%
# epoch: 371 training loss:  3.155 training accuracy:  7.8%  test loss:  3.620 test accuracy:  3.3%
# epoch: 372 training loss:  3.154 training accuracy:  7.8%  test loss:  3.621 test accuracy:  3.3%
# epoch: 373 training loss:  3.153 training accuracy:  7.8%  test loss:  3.623 test accuracy:  3.3%
# epoch: 374 training loss:  3.153 training accuracy:  7.8%  test loss:  3.624 test accuracy:  3.3%
# epoch: 375 training loss:  3.152 training accuracy:  7.8%  test loss:  3.626 test accuracy:  3.3%
# epoch: 376 training loss:  3.151 training accuracy:  7.8%  test loss:  3.627 test accuracy:  3.3%
# epoch: 377 training loss:  3.151 training accuracy:  7.8%  test loss:  3.629 test accuracy:  3.3%
# epoch: 378 training loss:  3.150 training accuracy:  7.8%  test loss:  3.630 test accuracy:  3.3%
# epoch: 379 training loss:  3.149 training accuracy:  7.8%  test loss:  3.632 test accuracy:  3.3%
# epoch: 380 training loss:  3.148 training accuracy:  7.8%  test loss:  3.633 test accuracy:  3.3%
# epoch: 381 training loss:  3.148 training accuracy:  7.8%  test loss:  3.635 test accuracy:  3.3%
# epoch: 382 training loss:  3.147 training accuracy:  7.8%  test loss:  3.636 test accuracy:  3.3%
# epoch: 383 training loss:  3.146 training accuracy:  7.8%  test loss:  3.637 test accuracy:  3.3%
# epoch: 384 training loss:  3.146 training accuracy:  7.8%  test loss:  3.639 test accuracy:  3.3%
# epoch: 385 training loss:  3.145 training accuracy:  7.8%  test loss:  3.640 test accuracy:  3.3%
# epoch: 386 training loss:  3.144 training accuracy:  7.8%  test loss:  3.642 test accuracy:  3.3%
# epoch: 387 training loss:  3.144 training accuracy:  7.8%  test loss:  3.643 test accuracy:  3.3%
# epoch: 388 training loss:  3.143 training accuracy:  7.8%  test loss:  3.645 test accuracy:  3.3%
# epoch: 389 training loss:  3.142 training accuracy:  7.8%  test loss:  3.646 test accuracy:  3.3%
# epoch: 390 training loss:  3.142 training accuracy:  7.8%  test loss:  3.648 test accuracy:  3.3%
# epoch: 391 training loss:  3.141 training accuracy:  7.8%  test loss:  3.649 test accuracy:  3.3%
# epoch: 392 training loss:  3.140 training accuracy:  7.8%  test loss:  3.650 test accuracy:  3.3%
# epoch: 393 training loss:  3.140 training accuracy:  7.8%  test loss:  3.652 test accuracy:  3.3%
# epoch: 394 training loss:  3.139 training accuracy:  7.8%  test loss:  3.653 test accuracy:  3.3%
# epoch: 395 training loss:  3.138 training accuracy:  9.4%  test loss:  3.655 test accuracy:  3.3%
# epoch: 396 training loss:  3.138 training accuracy:  9.4%  test loss:  3.656 test accuracy:  3.3%
# epoch: 397 training loss:  3.137 training accuracy:  9.4%  test loss:  3.657 test accuracy:  3.3%
# epoch: 398 training loss:  3.136 training accuracy:  9.4%  test loss:  3.659 test accuracy:  3.3%
# epoch: 399 training loss:  3.136 training accuracy:  9.4%  test loss:  3.660 test accuracy:  3.3%
# epoch: 400 training loss:  3.135 training accuracy:  9.4%  test loss:  3.661 test accuracy:  3.3%
# epoch: 401 training loss:  3.134 training accuracy:  9.4%  test loss:  3.663 test accuracy:  3.3%
# epoch: 402 training loss:  3.134 training accuracy:  9.4%  test loss:  3.664 test accuracy:  3.3%
# epoch: 403 training loss:  3.133 training accuracy:  9.4%  test loss:  3.666 test accuracy:  3.3%
# epoch: 404 training loss:  3.132 training accuracy:  9.4%  test loss:  3.667 test accuracy:  3.3%
# epoch: 405 training loss:  3.132 training accuracy:  9.4%  test loss:  3.668 test accuracy:  3.3%
# epoch: 406 training loss:  3.131 training accuracy:  9.4%  test loss:  3.670 test accuracy:  3.3%
# epoch: 407 training loss:  3.130 training accuracy:  9.4%  test loss:  3.671 test accuracy:  3.3%
# epoch: 408 training loss:  3.130 training accuracy:  9.4%  test loss:  3.672 test accuracy:  3.3%
# epoch: 409 training loss:  3.129 training accuracy:  9.4%  test loss:  3.674 test accuracy:  3.3%
# epoch: 410 training loss:  3.128 training accuracy:  9.4%  test loss:  3.675 test accuracy:  3.3%
# epoch: 411 training loss:  3.128 training accuracy:  9.4%  test loss:  3.676 test accuracy:  3.3%
# epoch: 412 training loss:  3.127 training accuracy:  9.4%  test loss:  3.678 test accuracy:  3.3%
# epoch: 413 training loss:  3.127 training accuracy:  9.4%  test loss:  3.679 test accuracy:  3.3%
# epoch: 414 training loss:  3.126 training accuracy:  9.4%  test loss:  3.680 test accuracy:  3.3%
# epoch: 415 training loss:  3.125 training accuracy:  9.4%  test loss:  3.681 test accuracy:  3.3%
# epoch: 416 training loss:  3.125 training accuracy:  9.4%  test loss:  3.683 test accuracy:  3.3%
# epoch: 417 training loss:  3.124 training accuracy:  9.4%  test loss:  3.684 test accuracy:  3.3%
# epoch: 418 training loss:  3.123 training accuracy:  9.4%  test loss:  3.686 test accuracy:  3.3%
# epoch: 419 training loss:  3.123 training accuracy:  9.4%  test loss:  3.687 test accuracy:  3.3%
# epoch: 420 training loss:  3.122 training accuracy:  9.4%  test loss:  3.688 test accuracy:  3.3%
# epoch: 421 training loss:  3.121 training accuracy:  9.4%  test loss:  3.690 test accuracy:  3.3%
# epoch: 422 training loss:  3.121 training accuracy:  9.4%  test loss:  3.691 test accuracy:  3.3%
# epoch: 423 training loss:  3.120 training accuracy:  9.4%  test loss:  3.692 test accuracy:  3.3%
# epoch: 424 training loss:  3.119 training accuracy:  9.4%  test loss:  3.694 test accuracy:  3.3%
# epoch: 425 training loss:  3.119 training accuracy:  9.4%  test loss:  3.695 test accuracy:  3.3%
# epoch: 426 training loss:  3.118 training accuracy:  9.4%  test loss:  3.696 test accuracy:  3.3%
# epoch: 427 training loss:  3.117 training accuracy:  9.4%  test loss:  3.698 test accuracy:  3.3%
# epoch: 428 training loss:  3.117 training accuracy:  9.4%  test loss:  3.699 test accuracy:  3.3%
# epoch: 429 training loss:  3.116 training accuracy:  9.4%  test loss:  3.701 test accuracy:  3.3%
# epoch: 430 training loss:  3.115 training accuracy:  9.4%  test loss:  3.702 test accuracy:  3.3%
# epoch: 431 training loss:  3.115 training accuracy:  9.4%  test loss:  3.703 test accuracy:  3.3%
# epoch: 432 training loss:  3.114 training accuracy:  9.4%  test loss:  3.705 test accuracy:  3.3%
# epoch: 433 training loss:  3.113 training accuracy:  9.4%  test loss:  3.706 test accuracy:  3.3%
# epoch: 434 training loss:  3.113 training accuracy:  9.4%  test loss:  3.707 test accuracy:  3.3%
# epoch: 435 training loss:  3.112 training accuracy:  9.4%  test loss:  3.709 test accuracy:  3.3%
# epoch: 436 training loss:  3.111 training accuracy:  9.4%  test loss:  3.710 test accuracy:  3.3%
# epoch: 437 training loss:  3.111 training accuracy:  9.4%  test loss:  3.712 test accuracy:  3.3%
# epoch: 438 training loss:  3.110 training accuracy:  9.4%  test loss:  3.713 test accuracy:  3.3%
# epoch: 439 training loss:  3.109 training accuracy:  9.4%  test loss:  3.714 test accuracy:  3.3%
# epoch: 440 training loss:  3.108 training accuracy:  9.4%  test loss:  3.716 test accuracy:  3.3%
# epoch: 441 training loss:  3.108 training accuracy:  9.4%  test loss:  3.717 test accuracy:  3.2%
# epoch: 442 training loss:  3.107 training accuracy:  9.4%  test loss:  3.719 test accuracy:  3.2%
# epoch: 443 training loss:  3.106 training accuracy:  9.4%  test loss:  3.720 test accuracy:  3.2%
# epoch: 444 training loss:  3.105 training accuracy:  9.4%  test loss:  3.721 test accuracy:  3.2%
# epoch: 445 training loss:  3.105 training accuracy:  9.4%  test loss:  3.723 test accuracy:  3.2%
# epoch: 446 training loss:  3.104 training accuracy:  9.4%  test loss:  3.724 test accuracy:  3.2%
# epoch: 447 training loss:  3.103 training accuracy:  9.4%  test loss:  3.726 test accuracy:  3.2%
# epoch: 448 training loss:  3.102 training accuracy:  9.4%  test loss:  3.727 test accuracy:  3.2%
# epoch: 449 training loss:  3.102 training accuracy:  9.4%  test loss:  3.729 test accuracy:  3.2%
# epoch: 450 training loss:  3.101 training accuracy:  9.4%  test loss:  3.730 test accuracy:  3.2%
# epoch: 451 training loss:  3.100 training accuracy:  9.4%  test loss:  3.732 test accuracy:  3.2%
# epoch: 452 training loss:  3.099 training accuracy:  9.4%  test loss:  3.733 test accuracy:  3.2%
# epoch: 453 training loss:  3.099 training accuracy:  9.4%  test loss:  3.735 test accuracy:  3.2%
# epoch: 454 training loss:  3.098 training accuracy:  9.4%  test loss:  3.736 test accuracy:  3.2%
# epoch: 455 training loss:  3.097 training accuracy:  9.4%  test loss:  3.738 test accuracy:  3.2%
# epoch: 456 training loss:  3.096 training accuracy:  9.4%  test loss:  3.739 test accuracy:  3.2%
# epoch: 457 training loss:  3.095 training accuracy:  9.4%  test loss:  3.741 test accuracy:  3.2%
# epoch: 458 training loss:  3.095 training accuracy:  9.4%  test loss:  3.742 test accuracy:  3.2%
# epoch: 459 training loss:  3.094 training accuracy:  9.4%  test loss:  3.744 test accuracy:  3.3%
# epoch: 460 training loss:  3.093 training accuracy:  9.4%  test loss:  3.745 test accuracy:  3.3%
# epoch: 461 training loss:  3.092 training accuracy:  9.4%  test loss:  3.747 test accuracy:  3.3%
# epoch: 462 training loss:  3.091 training accuracy:  9.4%  test loss:  3.748 test accuracy:  3.3%
# epoch: 463 training loss:  3.090 training accuracy:  9.4%  test loss:  3.750 test accuracy:  3.3%
# epoch: 464 training loss:  3.089 training accuracy:  9.4%  test loss:  3.752 test accuracy:  3.3%
# epoch: 465 training loss:  3.089 training accuracy:  9.4%  test loss:  3.753 test accuracy:  3.3%
# epoch: 466 training loss:  3.088 training accuracy:  9.4%  test loss:  3.755 test accuracy:  3.3%
# epoch: 467 training loss:  3.087 training accuracy:  9.4%  test loss:  3.756 test accuracy:  3.3%
# epoch: 468 training loss:  3.086 training accuracy:  9.4%  test loss:  3.758 test accuracy:  3.3%
# epoch: 469 training loss:  3.085 training accuracy:  9.4%  test loss:  3.760 test accuracy:  3.2%
# epoch: 470 training loss:  3.084 training accuracy:  9.4%  test loss:  3.761 test accuracy:  3.2%
# epoch: 471 training loss:  3.083 training accuracy:  9.4%  test loss:  3.763 test accuracy:  3.2%
# epoch: 472 training loss:  3.082 training accuracy:  9.4%  test loss:  3.765 test accuracy:  3.2%
# epoch: 473 training loss:  3.081 training accuracy:  9.4%  test loss:  3.767 test accuracy:  3.2%
# epoch: 474 training loss:  3.080 training accuracy:  9.4%  test loss:  3.768 test accuracy:  3.2%
# epoch: 475 training loss:  3.079 training accuracy:  9.4%  test loss:  3.770 test accuracy:  3.2%
# epoch: 476 training loss:  3.078 training accuracy:  9.4%  test loss:  3.772 test accuracy:  3.2%
# epoch: 477 training loss:  3.077 training accuracy:  9.4%  test loss:  3.774 test accuracy:  3.3%
# epoch: 478 training loss:  3.076 training accuracy:  9.4%  test loss:  3.775 test accuracy:  3.3%
# epoch: 479 training loss:  3.075 training accuracy:  9.4%  test loss:  3.777 test accuracy:  3.3%
# epoch: 480 training loss:  3.074 training accuracy:  9.4%  test loss:  3.779 test accuracy:  3.2%
# epoch: 481 training loss:  3.073 training accuracy:  9.4%  test loss:  3.781 test accuracy:  3.2%
# epoch: 482 training loss:  3.072 training accuracy:  9.4%  test loss:  3.783 test accuracy:  3.2%
# epoch: 483 training loss:  3.071 training accuracy:  9.4%  test loss:  3.785 test accuracy:  3.2%
# epoch: 484 training loss:  3.070 training accuracy:  9.4%  test loss:  3.787 test accuracy:  3.2%
# epoch: 485 training loss:  3.069 training accuracy:  9.4%  test loss:  3.789 test accuracy:  3.2%
# epoch: 486 training loss:  3.067 training accuracy:  9.4%  test loss:  3.791 test accuracy:  3.2%
# epoch: 487 training loss:  3.066 training accuracy:  9.4%  test loss:  3.793 test accuracy:  3.2%
# epoch: 488 training loss:  3.065 training accuracy:  10.9%  test loss:  3.795 test accuracy:  3.2%
# epoch: 489 training loss:  3.064 training accuracy:  10.9%  test loss:  3.797 test accuracy:  3.2%
# ...
# epoch: 842 training loss:  0.012 training accuracy:  100.0%  test loss:  22.036 test accuracy:  4.0%
# epoch: 843 training loss:  0.012 training accuracy:  100.0%  test loss:  22.060 test accuracy:  4.0%
# epoch: 844 training loss:  0.012 training accuracy:  100.0%  test loss:  22.082 test accuracy:  4.1%
# epoch: 845 training loss:  0.012 training accuracy:  100.0%  test loss:  22.104 test accuracy:  4.1%
# epoch: 846 training loss:  0.012 training accuracy:  100.0%  test loss:  22.127 test accuracy:  4.1%
# epoch: 847 training loss:  0.012 training accuracy:  100.0%  test loss:  22.150 test accuracy:  4.0%
# epoch: 848 training loss:  0.012 training accuracy:  100.0%  test loss:  22.172 test accuracy:  4.0%
# epoch: 849 training loss:  0.012 training accuracy:  100.0%  test loss:  22.194 test accuracy:  4.1%
# epoch: 850 training loss:  0.011 training accuracy:  100.0%  test loss:  22.214 test accuracy:  4.1%
# epoch: 851 training loss:  0.011 training accuracy:  100.0%  test loss:  22.234 test accuracy:  4.1%
# epoch: 852 training loss:  0.011 training accuracy:  100.0%  test loss:  22.255 test accuracy:  4.1%
# epoch: 853 training loss:  0.011 training accuracy:  100.0%  test loss:  22.277 test accuracy:  4.1%
# epoch: 854 training loss:  0.011 training accuracy:  100.0%  test loss:  22.300 test accuracy:  4.1%
# epoch: 855 training loss:  0.011 training accuracy:  100.0%  test loss:  22.322 test accuracy:  4.1%
# epoch: 856 training loss:  0.011 training accuracy:  100.0%  test loss:  22.342 test accuracy:  4.1%
# epoch: 857 training loss:  0.011 training accuracy:  100.0%  test loss:  22.362 test accuracy:  4.1%
# epoch: 858 training loss:  0.011 training accuracy:  100.0%  test loss:  22.382 test accuracy:  4.1%
# epoch: 859 training loss:  0.011 training accuracy:  100.0%  test loss:  22.402 test accuracy:  4.1%
# epoch: 860 training loss:  0.011 training accuracy:  100.0%  test loss:  22.422 test accuracy:  4.1%
# epoch: 861 training loss:  0.010 training accuracy:  100.0%  test loss:  22.442 test accuracy:  4.1%
# epoch: 862 training loss:  0.010 training accuracy:  100.0%  test loss:  22.462 test accuracy:  4.1%
# epoch: 863 training loss:  0.010 training accuracy:  100.0%  test loss:  22.482 test accuracy:  4.1%
# epoch: 864 training loss:  0.010 training accuracy:  100.0%  test loss:  22.501 test accuracy:  4.1%
# epoch: 865 training loss:  0.010 training accuracy:  100.0%  test loss:  22.522 test accuracy:  4.1%
# epoch: 866 training loss:  0.010 training accuracy:  100.0%  test loss:  22.542 test accuracy:  4.1%
# epoch: 867 training loss:  0.010 training accuracy:  100.0%  test loss:  22.562 test accuracy:  4.0%
# epoch: 868 training loss:  0.010 training accuracy:  100.0%  test loss:  22.582 test accuracy:  4.0%
# epoch: 869 training loss:  0.010 training accuracy:  100.0%  test loss:  22.600 test accuracy:  4.0%
# epoch: 870 training loss:  0.010 training accuracy:  100.0%  test loss:  22.617 test accuracy:  4.1%
# epoch: 871 training loss:  0.010 training accuracy:  100.0%  test loss:  22.635 test accuracy:  4.1%
# epoch: 872 training loss:  0.010 training accuracy:  100.0%  test loss:  22.654 test accuracy:  4.1%
# epoch: 873 training loss:  0.010 training accuracy:  100.0%  test loss:  22.673 test accuracy:  4.1%
# epoch: 874 training loss:  0.009 training accuracy:  100.0%  test loss:  22.694 test accuracy:  4.1%
# epoch: 875 training loss:  0.009 training accuracy:  100.0%  test loss:  22.713 test accuracy:  4.0%
# epoch: 876 training loss:  0.009 training accuracy:  100.0%  test loss:  22.732 test accuracy:  4.0%
# epoch: 877 training loss:  0.009 training accuracy:  100.0%  test loss:  22.750 test accuracy:  4.0%
# epoch: 878 training loss:  0.009 training accuracy:  100.0%  test loss:  22.768 test accuracy:  4.0%
# epoch: 879 training loss:  0.009 training accuracy:  100.0%  test loss:  22.785 test accuracy:  4.1%
# epoch: 880 training loss:  0.009 training accuracy:  100.0%  test loss:  22.803 test accuracy:  4.1%
# epoch: 881 training loss:  0.009 training accuracy:  100.0%  test loss:  22.821 test accuracy:  4.1%
# epoch: 882 training loss:  0.009 training accuracy:  100.0%  test loss:  22.839 test accuracy:  4.1%
# epoch: 883 training loss:  0.009 training accuracy:  100.0%  test loss:  22.856 test accuracy:  4.1%
# epoch: 884 training loss:  0.009 training accuracy:  100.0%  test loss:  22.873 test accuracy:  4.0%
# epoch: 885 training loss:  0.009 training accuracy:  100.0%  test loss:  22.892 test accuracy:  4.0%
# epoch: 886 training loss:  0.009 training accuracy:  100.0%  test loss:  22.910 test accuracy:  4.1%
# epoch: 887 training loss:  0.009 training accuracy:  100.0%  test loss:  22.928 test accuracy:  4.1%
# epoch: 888 training loss:  0.009 training accuracy:  100.0%  test loss:  22.945 test accuracy:  4.1%
# epoch: 889 training loss:  0.009 training accuracy:  100.0%  test loss:  22.962 test accuracy:  4.1%
# epoch: 890 training loss:  0.008 training accuracy:  100.0%  test loss:  22.978 test accuracy:  4.0%
# epoch: 891 training loss:  0.008 training accuracy:  100.0%  test loss:  22.996 test accuracy:  4.0%
# epoch: 892 training loss:  0.008 training accuracy:  100.0%  test loss:  23.014 test accuracy:  4.0%
# epoch: 893 training loss:  0.008 training accuracy:  100.0%  test loss:  23.032 test accuracy:  4.0%
# epoch: 894 training loss:  0.008 training accuracy:  100.0%  test loss:  23.048 test accuracy:  4.1%
# epoch: 895 training loss:  0.008 training accuracy:  100.0%  test loss:  23.064 test accuracy:  4.1%
# epoch: 896 training loss:  0.008 training accuracy:  100.0%  test loss:  23.079 test accuracy:  4.1%
# epoch: 897 training loss:  0.008 training accuracy:  100.0%  test loss:  23.095 test accuracy:  4.1%
# epoch: 898 training loss:  0.008 training accuracy:  100.0%  test loss:  23.111 test accuracy:  4.0%
# epoch: 899 training loss:  0.008 training accuracy:  100.0%  test loss:  23.128 test accuracy:  4.0%
# epoch: 900 training loss:  0.008 training accuracy:  100.0%  test loss:  23.146 test accuracy:  4.0%
# epoch: 901 training loss:  0.008 training accuracy:  100.0%  test loss:  23.163 test accuracy:  4.0%
# epoch: 902 training loss:  0.008 training accuracy:  100.0%  test loss:  23.179 test accuracy:  4.0%
# epoch: 903 training loss:  0.008 training accuracy:  100.0%  test loss:  23.195 test accuracy:  4.1%
# epoch: 904 training loss:  0.008 training accuracy:  100.0%  test loss:  23.209 test accuracy:  4.0%
# epoch: 905 training loss:  0.008 training accuracy:  100.0%  test loss:  23.225 test accuracy:  4.0%
# epoch: 906 training loss:  0.008 training accuracy:  100.0%  test loss:  23.240 test accuracy:  4.1%
# epoch: 907 training loss:  0.008 training accuracy:  100.0%  test loss:  23.257 test accuracy:  4.1%
# epoch: 908 training loss:  0.008 training accuracy:  100.0%  test loss:  23.273 test accuracy:  4.1%
# epoch: 909 training loss:  0.008 training accuracy:  100.0%  test loss:  23.288 test accuracy:  4.1%
# epoch: 910 training loss:  0.007 training accuracy:  100.0%  test loss:  23.303 test accuracy:  4.1%
# epoch: 911 training loss:  0.007 training accuracy:  100.0%  test loss:  23.318 test accuracy:  4.1%
# epoch: 912 training loss:  0.007 training accuracy:  100.0%  test loss:  23.334 test accuracy:  4.0%
# epoch: 913 training loss:  0.007 training accuracy:  100.0%  test loss:  23.350 test accuracy:  4.0%
# epoch: 914 training loss:  0.007 training accuracy:  100.0%  test loss:  23.366 test accuracy:  4.0%
# epoch: 915 training loss:  0.007 training accuracy:  100.0%  test loss:  23.381 test accuracy:  4.0%
# epoch: 916 training loss:  0.007 training accuracy:  100.0%  test loss:  23.396 test accuracy:  4.0%
# epoch: 917 training loss:  0.007 training accuracy:  100.0%  test loss:  23.410 test accuracy:  4.0%
# epoch: 918 training loss:  0.007 training accuracy:  100.0%  test loss:  23.424 test accuracy:  4.1%
# epoch: 919 training loss:  0.007 training accuracy:  100.0%  test loss:  23.439 test accuracy:  4.0%
# epoch: 920 training loss:  0.007 training accuracy:  100.0%  test loss:  23.453 test accuracy:  4.0%
# epoch: 921 training loss:  0.007 training accuracy:  100.0%  test loss:  23.469 test accuracy:  4.0%
# epoch: 922 training loss:  0.007 training accuracy:  100.0%  test loss:  23.484 test accuracy:  4.1%
# epoch: 923 training loss:  0.007 training accuracy:  100.0%  test loss:  23.498 test accuracy:  4.1%
# epoch: 924 training loss:  0.007 training accuracy:  100.0%  test loss:  23.513 test accuracy:  4.1%
# epoch: 925 training loss:  0.007 training accuracy:  100.0%  test loss:  23.527 test accuracy:  4.0%
# epoch: 926 training loss:  0.007 training accuracy:  100.0%  test loss:  23.542 test accuracy:  4.0%
# epoch: 927 training loss:  0.007 training accuracy:  100.0%  test loss:  23.556 test accuracy:  4.0%
# epoch: 928 training loss:  0.007 training accuracy:  100.0%  test loss:  23.570 test accuracy:  4.0%
# epoch: 929 training loss:  0.007 training accuracy:  100.0%  test loss:  23.584 test accuracy:  4.1%
# epoch: 930 training loss:  0.007 training accuracy:  100.0%  test loss:  23.598 test accuracy:  4.1%
# epoch: 931 training loss:  0.007 training accuracy:  100.0%  test loss:  23.613 test accuracy:  4.0%
# epoch: 932 training loss:  0.007 training accuracy:  100.0%  test loss:  23.627 test accuracy:  4.0%
# epoch: 933 training loss:  0.007 training accuracy:  100.0%  test loss:  23.642 test accuracy:  4.0%
# epoch: 934 training loss:  0.007 training accuracy:  100.0%  test loss:  23.656 test accuracy:  4.0%
# epoch: 935 training loss:  0.007 training accuracy:  100.0%  test loss:  23.670 test accuracy:  4.0%
# epoch: 936 training loss:  0.006 training accuracy:  100.0%  test loss:  23.683 test accuracy:  4.1%
# epoch: 937 training loss:  0.006 training accuracy:  100.0%  test loss:  23.695 test accuracy:  4.1%
# epoch: 938 training loss:  0.006 training accuracy:  100.0%  test loss:  23.708 test accuracy:  4.1%
# epoch: 939 training loss:  0.006 training accuracy:  100.0%  test loss:  23.722 test accuracy:  4.0%
# epoch: 940 training loss:  0.006 training accuracy:  100.0%  test loss:  23.736 test accuracy:  4.0%
# epoch: 941 training loss:  0.006 training accuracy:  100.0%  test loss:  23.750 test accuracy:  4.0%
# epoch: 942 training loss:  0.006 training accuracy:  100.0%  test loss:  23.765 test accuracy:  4.1%
# epoch: 943 training loss:  0.006 training accuracy:  100.0%  test loss:  23.779 test accuracy:  4.1%
# epoch: 944 training loss:  0.006 training accuracy:  100.0%  test loss:  23.792 test accuracy:  4.1%
# epoch: 945 training loss:  0.006 training accuracy:  100.0%  test loss:  23.804 test accuracy:  4.0%
# epoch: 946 training loss:  0.006 training accuracy:  100.0%  test loss:  23.816 test accuracy:  4.0%
# epoch: 947 training loss:  0.006 training accuracy:  100.0%  test loss:  23.829 test accuracy:  4.0%
# epoch: 948 training loss:  0.006 training accuracy:  100.0%  test loss:  23.842 test accuracy:  4.0%
# epoch: 949 training loss:  0.006 training accuracy:  100.0%  test loss:  23.856 test accuracy:  4.1%
# epoch: 950 training loss:  0.006 training accuracy:  100.0%  test loss:  23.869 test accuracy:  4.1%
# epoch: 951 training loss:  0.006 training accuracy:  100.0%  test loss:  23.883 test accuracy:  4.1%
# epoch: 952 training loss:  0.006 training accuracy:  100.0%  test loss:  23.896 test accuracy:  4.1%
# epoch: 953 training loss:  0.006 training accuracy:  100.0%  test loss:  23.909 test accuracy:  4.1%
# epoch: 954 training loss:  0.006 training accuracy:  100.0%  test loss:  23.921 test accuracy:  4.0%
# epoch: 955 training loss:  0.006 training accuracy:  100.0%  test loss:  23.933 test accuracy:  4.0%
# epoch: 956 training loss:  0.006 training accuracy:  100.0%  test loss:  23.945 test accuracy:  4.0%
# epoch: 957 training loss:  0.006 training accuracy:  100.0%  test loss:  23.958 test accuracy:  4.1%
# epoch: 958 training loss:  0.006 training accuracy:  100.0%  test loss:  23.970 test accuracy:  4.1%
# epoch: 959 training loss:  0.006 training accuracy:  100.0%  test loss:  23.984 test accuracy:  4.0%
# epoch: 960 training loss:  0.006 training accuracy:  100.0%  test loss:  23.997 test accuracy:  4.0%
# epoch: 961 training loss:  0.006 training accuracy:  100.0%  test loss:  24.010 test accuracy:  4.0%
# epoch: 962 training loss:  0.006 training accuracy:  100.0%  test loss:  24.023 test accuracy:  4.0%
# epoch: 963 training loss:  0.006 training accuracy:  100.0%  test loss:  24.035 test accuracy:  4.0%
# epoch: 964 training loss:  0.006 training accuracy:  100.0%  test loss:  24.046 test accuracy:  4.0%
# epoch: 965 training loss:  0.006 training accuracy:  100.0%  test loss:  24.057 test accuracy:  4.1%
# epoch: 966 training loss:  0.006 training accuracy:  100.0%  test loss:  24.069 test accuracy:  4.1%
# epoch: 967 training loss:  0.006 training accuracy:  100.0%  test loss:  24.082 test accuracy:  4.1%
# epoch: 968 training loss:  0.006 training accuracy:  100.0%  test loss:  24.094 test accuracy:  4.1%
# epoch: 969 training loss:  0.005 training accuracy:  100.0%  test loss:  24.107 test accuracy:  4.1%
# epoch: 970 training loss:  0.005 training accuracy:  100.0%  test loss:  24.120 test accuracy:  4.1%
# epoch: 971 training loss:  0.005 training accuracy:  100.0%  test loss:  24.131 test accuracy:  4.0%
# epoch: 972 training loss:  0.005 training accuracy:  100.0%  test loss:  24.143 test accuracy:  4.0%
# epoch: 973 training loss:  0.005 training accuracy:  100.0%  test loss:  24.154 test accuracy:  4.0%
# epoch: 974 training loss:  0.005 training accuracy:  100.0%  test loss:  24.166 test accuracy:  4.0%
# epoch: 975 training loss:  0.005 training accuracy:  100.0%  test loss:  24.178 test accuracy:  4.0%
# epoch: 976 training loss:  0.005 training accuracy:  100.0%  test loss:  24.190 test accuracy:  4.1%
# epoch: 977 training loss:  0.005 training accuracy:  100.0%  test loss:  24.202 test accuracy:  4.1%
# epoch: 978 training loss:  0.005 training accuracy:  100.0%  test loss:  24.213 test accuracy:  4.1%
# epoch: 979 training loss:  0.005 training accuracy:  100.0%  test loss:  24.224 test accuracy:  4.1%
# epoch: 980 training loss:  0.005 training accuracy:  100.0%  test loss:  24.235 test accuracy:  4.0%
# epoch: 981 training loss:  0.005 training accuracy:  100.0%  test loss:  24.247 test accuracy:  4.0%
# epoch: 982 training loss:  0.005 training accuracy:  100.0%  test loss:  24.259 test accuracy:  4.0%
# epoch: 983 training loss:  0.005 training accuracy:  100.0%  test loss:  24.271 test accuracy:  4.0%
# epoch: 984 training loss:  0.005 training accuracy:  100.0%  test loss:  24.284 test accuracy:  4.0%
# epoch: 985 training loss:  0.005 training accuracy:  100.0%  test loss:  24.295 test accuracy:  4.0%
# epoch: 986 training loss:  0.005 training accuracy:  100.0%  test loss:  24.306 test accuracy:  4.0%
# epoch: 987 training loss:  0.005 training accuracy:  100.0%  test loss:  24.317 test accuracy:  4.0%
# epoch: 988 training loss:  0.005 training accuracy:  100.0%  test loss:  24.328 test accuracy:  4.0%
# epoch: 989 training loss:  0.005 training accuracy:  100.0%  test loss:  24.339 test accuracy:  4.0%
# epoch: 990 training loss:  0.005 training accuracy:  100.0%  test loss:  24.350 test accuracy:  4.1%
# epoch: 991 training loss:  0.005 training accuracy:  100.0%  test loss:  24.362 test accuracy:  4.1%
# epoch: 992 training loss:  0.005 training accuracy:  100.0%  test loss:  24.373 test accuracy:  4.1%
# epoch: 993 training loss:  0.005 training accuracy:  100.0%  test loss:  24.383 test accuracy:  4.1%
# epoch: 994 training loss:  0.005 training accuracy:  100.0%  test loss:  24.394 test accuracy:  4.1%
# epoch: 995 training loss:  0.005 training accuracy:  100.0%  test loss:  24.405 test accuracy:  4.0%
# epoch: 996 training loss:  0.005 training accuracy:  100.0%  test loss:  24.416 test accuracy:  4.0%
# epoch: 997 training loss:  0.005 training accuracy:  100.0%  test loss:  24.427 test accuracy:  4.0%
# epoch: 998 training loss:  0.005 training accuracy:  100.0%  test loss:  24.438 test accuracy:  4.1%
# epoch: 999 training loss:  0.005 training accuracy:  100.0%  test loss:  24.449 test accuracy:  4.1%
# Wall time: 21min 26s

# %%
data = torch.load(results_path1)
statsrec = data["stats"]

fig, ax1 = plt.subplots()
plt.plot(statsrec[0], 'r', label = 'training loss', )
plt.plot(statsrec[2], 'g', label = 'test loss' )
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and test loss, and test accuracy')
ax2=ax1.twinx()
ax2.plot(statsrec[1], 'm', label = 'training accuracy')
ax2.plot(statsrec[3], 'b', label = 'test accuracy')
ax2.set_ylabel('accuracy')
plt.legend(loc='upper right')
fig.savefig("roc.svg")
plt.show()

# %% [markdown]
# ## 1.2 Training on complete dataset [23 marks]
#
# ### 1.2.1 Train CNN and show loss graph [6 marks]
#
# Train your model on the complete training dataset, and use the validation set to determine when to stop training.
#
# Display the graph of training and validation loss over epochs to show how you determined the optimal number of training epochs.
#
# > As in previous sections, please leave the graph clearly displayed.

# %%
# %%time
# TO COMPLETE
nepochs = 2
n_epochs_stop = 10
epochs_no_improve = 0
early_stop=False
results_path = root+'/results/cnnclassifier_fulldataset.pt'
statsrec = np.zeros((4,nepochs))

min_val_loss=np.Inf
for epoch in range(nepochs):  # loop over the dataset multiple times
    correct = 0          # number of examples predicted correctly (for accuracy)
    total = 0            # number of examples
    running_loss = 0.0   # accumulated loss (for mean loss)
    n = 0                # number of minibatches
    for data in train_loader:
        input_s, label_s = data
        inputs, labels = input_s.to(device), label_s.to(device)
        
         # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward, backward, and update parameters
        outputs = net(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
    
        # accumulate loss
        running_loss += loss.item()
        n += 1
        # accumulate data for accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)    # add in the number of labels in this minibatch
        correct += (predicted == labels).sum().item()  # add in the number of correct labels
    # collect together statistics for this epoch
    ltrn = running_loss/n
    atrn = correct/total 
    ltst, atst = stats(validation_loader, net)
    ### early stop if there is not change in validation loss over 10 instances of the epochs.
    if ltst<min_val_loss:
        epochs_no_improve = 0
        min_val_loss = ltst
    else:
        epochs_no_improve+=1
    if epoch > 5 and epochs_no_improve == n_epochs_stop:
        print('Early stopping!' )
        early_stop = True
        break
    statsrec[:,epoch] = (ltrn, atrn, ltst, atst)
    print(f"epoch: {epoch} training loss: {ltrn: .3f} training accuracy: {atrn: .1%}  test loss: {ltst: .3f} test accuracy: {atst: .1%}")

# save network parameters, losses and accuracy
torch.save({"state_dict": net.state_dict(), "stats": statsrec}, results_path)
# Out:
# epoch: 0 training loss:  3.403 training accuracy:  2.7%  test loss:  3.362 test accuracy:  0.0%
# epoch: 1 training loss:  3.403 training accuracy:  2.7%  test loss:  3.362 test accuracy:  0.0%
# CPU times: user 1min 1s, sys: 2.74 s, total: 1min 4s
# Wall time: 55.1 s

# %%
model_save_name = 'cnnclassifier200epochs.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data = torch.load(results_path)
statsrec = data["stats"]

fig, ax1 = plt.subplots()
plt.plot(statsrec[0], 'r', label = 'training loss', )
plt.plot(statsrec[2], 'g', label = 'test loss' )
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and test loss, and test accuracy')
ax2=ax1.twinx()
ax2.plot(statsrec[1], 'm', label = 'training accuracy')
ax2.plot(statsrec[3], 'b', label = 'test accuracy')
ax2.set_ylabel('accuracy')
plt.legend(loc='upper right')
fig.savefig("roc1.svg")
plt.show()

# %% [markdown]
# ### 1.2.2 Finetuning [6 marks]
#
# Now finetune your architecture by implementing at least 2 methods of reducing overfitting and increasing the model's ability to generalise. You are encouraged to further adjust the model after you have done the minimum requirement, to increase your model performance. Please do not use any pre-trained weights from a model trained on ImageNet.

# %% [markdown]
# **Method 1:** Data augmentation of your choice

# %% [markdown]
# **Method 2:** Adding dropout and/or batch normalisation to the model

# %% [markdown]
# If you adjust the Model class, redefine it below and instantiate it as ```model_122a```, ```model_122b```, and so on.

# %%
## Applying Data augmentation
from torchvision.datasets import ImageFolder
trnsfrm = transforms.Compose([                        
   transforms.ToTensor(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.05),
    transforms.Normalize([0.5,0.5,0.5],[0.5,0.5,0.5]),
  
])

dataset = ImageFolder(root="/content/drive/MyDrive/train_set",transform=trnsfrm)
print(dataset)
print(len(dataset.classes))
train_size = int(0.90 * len(dataset))
validation_size = len(dataset) - train_size
train_dataset, validation_dataset = torch.utils.data.random_split(dataset, [train_size, validation_size])## spliting train_set for both train_dataset and validation_set.
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=True,num_workers=2)
validation_loader = torch.utils.data.DataLoader(validation_dataset,batch_size=64, shuffle=True,num_workers=2)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 13500
#     Root location: /content/drive/MyDrive/train_set
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.05)
#                Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
#            )
# 30

# %%
for data in train_loader:
      inputs, labels = data
      print(inputs[0].shape)
      break
# Out:
# torch.Size([3, 64, 64])

# %%
# Adding drop out
model_122 = nn.Sequential(
    nn.Conv2d(in_channels=3,out_channels=50, kernel_size=3,padding=1),  
    nn.ReLU(inplace=True), 
    nn.Conv2d(in_channels=50,out_channels=75,  kernel_size=3,padding=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(kernel_size=2, stride=2),
    nn.Dropout(p=0.5),  
    nn.Conv2d(in_channels=75,out_channels=125,  kernel_size=3,padding=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(kernel_size=2, stride=2),
    nn.Conv2d(in_channels=125,out_channels=256,  kernel_size=3,padding=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(kernel_size=2, stride=2),
    nn.Dropout(p=0.25),
    nn.Flatten(),
    nn.Linear(256*8*8,1000), 
    nn.Dropout(p=0.25),  
    nn.Linear(1000,500),
    nn.Dropout(p=0.25),  
    nn.Linear(500,200),
    nn.Dropout(p=0.5),
    nn.Linear(200,30)
)

for param in model_122.parameters():
    print(param.shape)
# Out:
# torch.Size([50, 3, 3, 3])
# torch.Size([50])
# torch.Size([75, 50, 3, 3])
# torch.Size([75])
# torch.Size([125, 75, 3, 3])
# torch.Size([125])
# torch.Size([256, 125, 3, 3])
# torch.Size([256])
# torch.Size([1000, 16384])
# torch.Size([1000])
# torch.Size([500, 1000])
# torch.Size([500])
# torch.Size([200, 500])
# torch.Size([200])
# torch.Size([30, 200])
# torch.Size([30])

# %%
def stats1(loader, model_122):
    correct = 0
    total = 0
    running_loss = 0
    n = 0    # counter for number of minibatches
    with torch.no_grad():
        for data in loader:
            images, labels = data
            outputs = model_122(images)      
            
            # accumulate loss
            running_loss += loss_fn(outputs, labels)
            n += 1
            
            # accumulate data for accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)    # add in the number of labels in this minibatch
            correct += (predicted == labels).sum().item()  # add in the number of correct labels
            
    return running_loss/n, correct/total

# %%
## Adding learning scheduler.
from torch.optim import lr_scheduler
nepochs = 50
model_save_name = 'cnnclassifierepochs_finetune.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
statsrec = np.zeros((4,nepochs))
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_122.parameters(), lr=0.001)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5)## lr will change with patience 5
min_val_loss=np.Inf
for epoch in range(nepochs):  # loop over the dataset multiple times
    correct = 0          # number of examples predicted correctly (for accuracy)
    total = 0            # number of examples
    running_loss = 0.0   # accumulated loss (for mean loss)
    n = 0
    for data in train_loader:
        inputs, labels = data
        
         # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward, backward, and update parameters
        outputs = model_122(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
    
        # accumulate loss
        running_loss += loss.item()
        n += 1
        # accumulate data for accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)    # add in the number of labels in this minibatch
        correct += (predicted == labels).sum().item()  # add in the number of correct labels
    # collect together statistics for this epoch
    ltrn = running_loss/n
    atrn = correct/total 
    ltst, atst = stats1(validation_loader, model_122)
    scheduler.step(ltst/len(validation_loader))
    statsrec[:,epoch] = (ltrn, atrn, ltst, atst)
    print(f"epoch: {epoch} training loss: {ltrn: .3f} training accuracy: {atrn: .1%}  test loss: {ltst: .3f} test accuracy: {atst: .1%}")
# save network parameters, losses and accuracy
torch.save({"state_dict": model_122.state_dict(), "stats": statsrec}, results_path)
# Out:
# epoch: 0 training loss:  3.253 training accuracy:  7.8%  test loss:  3.155 test accuracy:  10.4%
# epoch: 1 training loss:  2.976 training accuracy:  14.0%  test loss:  2.913 test accuracy:  16.5%
# epoch: 2 training loss:  2.787 training accuracy:  18.1%  test loss:  2.692 test accuracy:  20.8%
# epoch: 3 training loss:  2.612 training accuracy:  22.7%  test loss:  2.566 test accuracy:  24.4%
# epoch: 4 training loss:  2.506 training accuracy:  26.4%  test loss:  2.603 test accuracy:  24.3%
# epoch: 5 training loss:  2.426 training accuracy:  28.5%  test loss:  2.485 test accuracy:  29.5%
# epoch: 6 training loss:  2.360 training accuracy:  30.3%  test loss:  2.425 test accuracy:  30.5%
# epoch: 7 training loss:  2.298 training accuracy:  32.0%  test loss:  2.330 test accuracy:  31.0%
# epoch: 8 training loss:  2.253 training accuracy:  33.4%  test loss:  2.279 test accuracy:  31.7%
# epoch: 9 training loss:  2.218 training accuracy:  35.2%  test loss:  2.283 test accuracy:  32.9%
# epoch: 10 training loss:  2.163 training accuracy:  37.0%  test loss:  2.310 test accuracy:  36.0%
# epoch: 11 training loss:  2.146 training accuracy:  36.9%  test loss:  2.131 test accuracy:  37.9%
# epoch: 12 training loss:  2.111 training accuracy:  38.2%  test loss:  2.182 test accuracy:  36.0%
# epoch: 13 training loss:  2.088 training accuracy:  38.4%  test loss:  2.123 test accuracy:  37.8%
# epoch: 14 training loss:  2.077 training accuracy:  39.2%  test loss:  2.188 test accuracy:  37.0%
# epoch: 15 training loss:  2.052 training accuracy:  39.6%  test loss:  2.144 test accuracy:  38.7%
# epoch: 16 training loss:  2.028 training accuracy:  40.4%  test loss:  2.175 test accuracy:  39.3%
# epoch: 17 training loss:  2.014 training accuracy:  40.7%  test loss:  2.178 test accuracy:  37.5%
# epoch: 18 training loss:  1.998 training accuracy:  41.4%  test loss:  2.164 test accuracy:  37.0%
# epoch: 19 training loss:  1.976 training accuracy:  41.6%  test loss:  2.161 test accuracy:  36.4%
# epoch: 20 training loss:  1.808 training accuracy:  46.8%  test loss:  2.001 test accuracy:  43.0%
# epoch: 21 training loss:  1.752 training accuracy:  48.1%  test loss:  2.009 test accuracy:  43.5%
# epoch: 22 training loss:  1.726 training accuracy:  48.4%  test loss:  1.964 test accuracy:  44.0%
# epoch: 23 training loss:  1.709 training accuracy:  49.3%  test loss:  1.989 test accuracy:  43.3%
# epoch: 24 training loss:  1.711 training accuracy:  48.6%  test loss:  1.931 test accuracy:  45.2%
# epoch: 25 training loss:  1.704 training accuracy:  49.5%  test loss:  1.932 test accuracy:  43.6%
# epoch: 26 training loss:  1.689 training accuracy:  49.4%  test loss:  1.958 test accuracy:  44.7%
# epoch: 27 training loss:  1.702 training accuracy:  49.2%  test loss:  1.942 test accuracy:  46.4%
# epoch: 28 training loss:  1.681 training accuracy:  50.0%  test loss:  1.934 test accuracy:  45.5%
# epoch: 29 training loss:  1.665 training accuracy:  50.5%  test loss:  1.945 test accuracy:  43.3%
# epoch: 30 training loss:  1.663 training accuracy:  50.5%  test loss:  1.950 test accuracy:  44.7%
# epoch: 31 training loss:  1.650 training accuracy:  51.3%  test loss:  1.943 test accuracy:  45.9%
# epoch: 32 training loss:  1.644 training accuracy:  50.8%  test loss:  1.964 test accuracy:  44.1%
# epoch: 33 training loss:  1.649 training accuracy:  51.1%  test loss:  1.975 test accuracy:  44.5%
# epoch: 34 training loss:  1.626 training accuracy:  51.2%  test loss:  2.032 test accuracy:  45.1%
# epoch: 35 training loss:  1.635 training accuracy:  51.3%  test loss:  1.872 test accuracy:  45.8%
# epoch: 36 training loss:  1.636 training accuracy:  51.5%  test loss:  1.965 test accuracy:  45.2%
# epoch: 37 training loss:  1.633 training accuracy:  51.3%  test loss:  1.925 test accuracy:  44.9%
# epoch: 38 training loss:  1.641 training accuracy:  51.0%  test loss:  1.962 test accuracy:  45.0%
# epoch: 39 training loss:  1.634 training accuracy:  51.4%  test loss:  1.907 test accuracy:  45.8%
# epoch: 40 training loss:  1.637 training accuracy:  51.3%  test loss:  1.947 test accuracy:  45.3%
# epoch: 41 training loss:  1.637 training accuracy:  51.6%  test loss:  1.885 test accuracy:  45.2%
# epoch: 42 training loss:  1.626 training accuracy:  51.3%  test loss:  1.960 test accuracy:  45.1%
# epoch: 43 training loss:  1.633 training accuracy:  51.3%  test loss:  1.896 test accuracy:  46.4%
# epoch: 44 training loss:  1.632 training accuracy:  51.4%  test loss:  1.959 test accuracy:  44.9%
# epoch: 45 training loss:  1.627 training accuracy:  51.3%  test loss:  1.984 test accuracy:  45.9%
# epoch: 46 training loss:  1.628 training accuracy:  51.7%  test loss:  1.981 test accuracy:  45.6%
# epoch: 47 training loss:  1.627 training accuracy:  51.3%  test loss:  1.987 test accuracy:  44.4%
# epoch: 48 training loss:  1.618 training accuracy:  51.9%  test loss:  1.902 test accuracy:  46.7%
# epoch: 49 training loss:  1.628 training accuracy:  51.3%  test loss:  1.955 test accuracy:  43.9%

# %%
model_save_name = 'cnnclassifierepochs_finetune.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data = torch.load(results_path)
statsrec = data["stats"]

fig, ax1 = plt.subplots()
plt.plot(statsrec[0], 'r', label = 'training loss', )
plt.plot(statsrec[2], 'g', label = 'test loss' )
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and test loss, and test accuracy')
ax2=ax1.twinx()
ax2.plot(statsrec[1], 'm', label = 'training accuracy')
ax2.plot(statsrec[3], 'b', label = 'test accuracy')
ax2.set_ylabel('accuracy')
plt.legend(loc='upper right')
fig.savefig("roc1.svg")
plt.show()

# %% [markdown]
# ### 1.2.3 Training comparison [4 marks]
#
# Display, side-by-side or on one single graph, the training and validation loss graphs for the single-batch training (section 1.1.3), on the full training set (1.2.1) and your final fine-tuned model (1.2.2).

# %%
ax = plt.subplot(2,2,1)
model_save_name = 'cnnclassifierepochs_finetune.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data = torch.load(results_path)
statsrec = data["stats"]
plt.plot(statsrec[1], 'r', label =  'training accuracy', )
plt.plot(statsrec[3], 'g', label =  'test accuracy' )
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Finetuning training')
plt.legend(loc='upper right')
plt.show()


ax = plt.subplot(2,2,1)
model_save_name = 'cnnclassifier200epochs.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data = torch.load(results_path)
statsrec = data["stats"]
plt.plot(statsrec[1], 'r', label =  'training accuracy', )
plt.plot(statsrec[3], 'g', label =  'test accuracy' )
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Whole training dataset training')
plt.legend(loc='upper right')
plt.show()

ax = plt.subplot(2,2,1)
model_save_name = 'cnnclassifiersinglebatch.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data = torch.load(results_path)
statsrec = data["stats"]
plt.plot(statsrec[1], 'r', label =  'training accuracy', )
plt.plot(statsrec[3], 'g', label =  'test accuracy' )
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Single batch training')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# From single batch training we can observe that we cant acheive minimum acccuraacy for the validation data in through the epochs while training accuracy is increasing.
#
# When trining on whole data set we can see that, by the end of the 50 epochs we got the validation accuracy of 35 percent and after that there we not observing any improvemnt in the validation loss .
#
#
# After applying certain  data agumentation techniques mod,ifying the model layers (add dropout and linear layers)aand adding lr scheduler we can observer slight increase the the accuracy of the validation to 45 percent.
#
# --> Double click here to respond

# %% [markdown]
# ### 1.2.4 Confusion matrices [7 marks]
#
# Use your architecture with best accuracy to generate two confusion matrices, one for the training set and one for the validation set. Remember to use the whole validation and training sets, and to include all your relevant code. Display the confusion matrices in a meaningful way which clearly indicates what percentage of the data is represented in each position.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
model_save_name = 'cnnclassifierepochs_finetune.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data=torch.load(results_path)
model_122.load_state_dict(data["state_dict"])
model_122.eval()
y_pred = []
y_true = []
class_list=[]
for key in dataset.class_to_idx.keys():
   class_list.append(key)
# iterate over test data
for inputs, labels in train_loader:
        output = model_122(inputs) # Feed Network
       # _, predicted = torch.max(outputs.data, 1)

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        #output = predicted.numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth


# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in class_list],
                     columns = [i for i in class_list])
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True)
plt.savefig('output.png')

# %% [markdown]
# What conclusions can be drawn from the confusion matrices?

# %% [markdown]
# We got certain class with more tha 20 percent correct predictions such as lion, jelly fish,bison, cardigan and pizza. However, we got false negatives for certain classes like pig, red panda classes where it is classfied wrongly as bison(animal). And other minor false negatives are bee, ice cream, pretezel, pizza which are classified as lion.

# %% [markdown]
# ## 1.3 Testing on test data [18 marks]
#
# ### 1.3.1 Dataset and generating predictions [6 marks]
#
# Create a PyTorch ```Dataset``` for the unlabeled test data in the test_set folder of the Kaggle competition and generate predictions using your final model.

# %%
# TO COMPLETE
model_save_name = 'cnnclassifierepochs_finetune.pt'
results_path = F"/content/drive/MyDrive/AI/{model_save_name}"
data=torch.load(results_path)
model_122.load_state_dict(data["state_dict"])
model_122.eval()
dataset = LoadFromFolder(main_dir="/content/drive/MyDrive/test_set",transform=trnsfrm )

# %%
from torch.utils.data import DataLoader
predicted_list=[]
for i in range(len(dataset)):
  image_name, image =dataset.__getitem__(i)
  outputs=model_122(image)#
  _, predicted = torch.max(outputs.data, 1)
  data = [image_name,predicted.numpy()[0] ]  
  predicted_list.append(data)
  # write a row to the csv file

# %% [markdown]
# ### 1.3.2 CSV file and test set accuracy [12 marks]
#
# Save all test predictions to a CSV file and submit it to the private class Kaggle competition. **Please save your test CSV file submissions using your student username (the one with letters, ie., ``sc15jb``, not the ID with only numbers)**, for example, `sc15jb.csv`. That will help us to identify your submissions.
#
# The CSV file must contain only two columns: ‘Id’ and ‘Category’ (predicted class ID) as shown below:
#
# ```txt
# Id,Category
# 28d0f5e9_373c.JPEG,2
# bbe4895f_40bf.JPEG,18
# ```
#
# The ‘Id’ column should include the name of the image. It is important to keep the same name as the one on the test set. Do not include any path, just the name of file (with extension). Your csv file must contain 1501 rows, one for each image on test set and 1 row for the headers.
#
# > You may submit multiple times. We will use your personal top entry for allocating marks for this [10 marks]. The class leaderboard will not affect marking (brownie points!).

# %%
# TO COMPLE

# %%
from csv import writer
 
  


with open("/content/drive/MyDrive/AI/sc21vp.csv", 'a', newline='') as f_object:  
    # Pass the CSV  file object to the writer() function
    writer_object = writer(f_object)
    # Result - a writer object
    # Pass the data in the list as an argument into the writerow() function
    for list_data in predicted_list:
     writer_object.writerow(list_data)  
    # Close the file object
    f_object.close()

# %% [markdown]
# ## QUESTION 2 [40 marks]
#
#
#
# In this question, you will visualize the filters and feature maps of a fully-trained CNN (AlexNet) on the full ImageNet 2012 dataset.
#
# > Please do not alter the name of the function or the number and type of its arguments and return values, otherwise the automatic grading function will not work correctly. You are welcome to import other modules (though the simplest solution only requires the ones below).

# %% [markdown]
# ### **Overview:**
# *   **2.1.1** Extract filters from model: ``fetch_filters(layer_idx, model)``
# *   **2.2.1** Load test image
# *   **2.2.2** Extract feature maps for given test image: ``fetch_feature_maps(image, model)``
# *   **2.2.3** Display feature maps
# *   **2.3.1** Generate Grad-CAM heatmaps: ``generate_heatmap(output, class_id, model, image)``
# *   **2.3.2** Display heatmaps: add code to cell
# *   **2.3.3** Generate heatmaps for failure analysis

# %% [markdown]
# ### Loading a pre-trained model
#
# Run the cell below to load an AlexNet model with pre-trained weights.

# %%
model = torch.hub.load('pytorch/vision:v0.6.0', 'alexnet', pretrained=True)
model.eval()
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.6.0.zip" to /root/.cache/torch/hub/v0.6.0.zip
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
model.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(inplace=True)
#   (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace=True)
#   (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
model.features[0]
# Out:
# Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))

# %%
model.features[0].weight.shape
# Out:
# torch.Size([64, 3, 11, 11])

# %% [markdown]
# ## 2.1 Extract and visualize the filters [6 marks]
#
# In this section you will extract and visualize the filters from the pre-trained AlexNet.

# %% [markdown]
# ### 2.1.1 Extract filters [4 marks]
#
# Complete the following function ```fetch_filters``` to return all the filters from the convolutional layers at the given index in ```model.features``` (see printed model above for reference).
#
#
#
#
#
# > We will not test the behaviour of your function using invalid indices.

# %%
def fetch_filters(layer_idx, model):
    """ 
        Args:
            layer_idx (int): the index of model.features specifying which conv layer
            model (AlexNet): PyTorch AlexNet object
        Return:
            filters (Tensor):      
    """
    filters = model.features[layer_idx].weight.data.clone()
     
    return filters

# %%
# all the indices of the conv layers
conv_layer_idx = [0, 3, 6, 8, 10]

filters = []

for layer_idx in conv_layer_idx:
    filters.append(fetch_filters(layer_idx, model))

# %% [markdown]
# For your testing purposes, the following code blocks test the dimensions of the function output.

# %%
filters[0].shape
# Out:
# torch.Size([64, 3, 11, 11])

# %%
assert list(filters[0].shape) == [64, 3, 11, 11]

# %% [markdown]
# ### 2.1.2 Display filters [2 marks]
#
# The following code will visualize some of the filters from each layer. Play around with viewing filters at different depths into the network. Note that ```filters[0]``` could be viewed in colour if you prefer, whereas the subsequent layers must be viewed one channel at a time in grayscale.

# %%
# limit how many filters to show
to_show = 16

# compute the dimensions of the plot
plt_dim = int(math.sqrt(to_show))

# plot the first channel of each filter in a grid
for i, filt in enumerate(filters[0].numpy()[:to_show]):
    plt.subplot(plt_dim, plt_dim, i+1)
    plt.imshow(filt[0], cmap="gray")
    plt.axis('off')
plt.show()

# %% [markdown]
# ## 2.2 Extract and visualize feature maps [10 marks]
#
# In this section, you will pass a test image through the AlexNet and extract and visualize the resulting convolutional layer feature maps.
#
# Complete the following code cell to load the test image ```man_bike.JPEG```.

# %% [markdown]
# ### 2.2.1 Load test image [1 mark]

# %%
# TO COMPL# TO COMPLETE
from PIL import Image
im=Image.open("man_bike.JPEG").convert("RGB")
print(im)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F1411719B50>

# %% [markdown]
# Run the code cell below to apply the image transformation expected by the model.

# %%
# ImageNet normalisation values, to apply to the image transform
norm_mean = [0.485, 0.456, 0.406]
norm_std = [0.229, 0.224, 0.225]

data_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize(norm_mean, norm_std),
    ])

im = data_transform(im)

# %% [markdown]
# ### 2.2.2 Extract feature maps [5 marks]
#
# Complete the function below to pass the test image through a single forward pass of the network. We are interested in the outputs of the max pool layers (outputs of conv layers at model.features indices 0, 3, and 10) for best visualization. Note that the input should pass through *every layer* of the model.

# %%
def fetch_feature_maps(image, model):
    """
    Args:
        image (Tensor): a single input image with transform applied
        model (AlexNet): PyTorch AlexNet object
        
    Return:
        feature_maps (Tensor): all the feature maps from conv layers 
                    at indices 0, 3, and 10 (outputs of the MaxPool layers)
    """
     
    # we will save the conv layer weights in this list
    model_weights =[]
    #we will save the conv layers in this list
    conv_layers = []
    # get all the model children as list
    all_layers=[]
    counter = 0 
    maxpool=[]
    model_children = list(model.children())

    for j in range(len(model_children[0])):
        child= model_children[0][j]
        all_layers.append(child)
        if type(child) == nn.MaxPool2d:
            
            counter += 1
 

    print(counter)
    results = [all_layers[0](image)]
  
    for i in range(1, len(all_layers)):
        # pass the result from the last layer to the next layer
        x=all_layers[i](results[-1])
        results.append(x)
        if len(results[i][0][0]) == len(results[i-1][0][0])// 2:
          maxpool.append(x)
       
    # make a copy of the `results`
    maxpool=[torch.tensor(x,requires_grad=False) for x in maxpool ]
    
    return maxpool

# %%
feature_maps = fetch_feature_maps(im.unsqueeze(0), model)
# Out:
# 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# For your testing purposes, the following code block tests the dimensions of part of the function output. Note that the first dimension is the batch size.

# %%
assert len(feature_maps) == 3
assert list(feature_maps[0].shape) == [1, 64, 31, 31]

# %% [markdown]
# ### 2.2.3 Display feature maps [4 marks]
#
# Using the code for displaying filters as reference, write code in the block below to display the outputs of the first **16 feature maps from each of the 3 max-pool layers**.

# %%
 # limit
n = 16

 
plt_dim = int(math.sqrt(n))

# plot the 16 filters channel  of each grid
for i in range(3):
  for i, filt in enumerate(feature_maps[i][0].numpy()[:n]):
     plt.subplot(plt_dim, plt_dim, i+1)
     plt.imshow(filt, cmap="gray")
     plt.axis('off')
  plt.show()

# %% [markdown]
# ## 2.3 Understanding of filters and feature maps [7 marks]
#
# Respond in detail to the questions below. (Note that all text boxes can be formatted using Markdown if desired).
#
# ### 2.3.1 [3 marks]
# Describe what the three filters at indices 0, 4, and 6 from the first convolutional layer are detecting (reference the corresponding feature maps to support your discussion).

# %% [markdown]
# --> Double click here to respond.
#
# Neural networks are like a black box, and learned features in a Neural Network are not interpretable. You pass an input image, and the model returns the results.
#
# If only you could visualize the intermediate representation applied across different Convolutional layers in CNN to understand how the model learns. Understanding the working of the model will help to know the reason for incorrect predition that will lead to better fine tuning of the model and explain the decisions.
#
# For Filter at index '0':
#
# This layer of the filter will help to capture the raw feature like edges, corners. All these features are very basic patterns. The patterns observed at this layers will be used to obtain better combinations.
#
# For Filter at index '4':
#
# At this filter, the network pattern gets more complicated than at index '0'. The features extracted from previous layers will be used to make more combinations to identify better patterns. At index '4' we have increased filter size when compared to the index at '0'. It will be able to detect more complex pattern at this stage.
#
# For Filter at index '6':
#
# As we are going deeper into the network depth.

# %% [markdown]
# ### 2.3.2 [2 marks]
# Discuss how the filters change with depth into the network.
#
# Every layer of filters is there to capture patterns. For example, the first layer of filters captures patterns like edges, corners, dots etc. Subsequent layers combine those patterns to make bigger patterns (like combining edges to make squares, circles, etc.).
#
# Now as we move forward in the layers, the patterns get more complex; hence there are larger combinations of patterns to capture. That's why we increase the filter size in subsequent layers to capture as many combinations as possible
#
# The higher the number of filters, the higher the number of abstractions that your Network is able to extract from image data. The reason why the number of filters is generally ascending is that at the input layer the Network receives raw pixel data. Raw data are always noisy, and this is especially true for image data.
#
# Because of this, we let CNNs extract first some relevant information from noisy, "dirty" raw pixel data. Once the useful features have been extracted, then we make the CNN elaborate more complex abstractions on it.
#
# That is why the number of filters usually increases as the Network gets deeper, even though it doesn't necessarily have to be like that.

# %% [markdown]
# --> Double click here to respond

# %% [markdown]
# ### 2.3.3 [2 marks]
# Discuss how the feature maps change with depth into the network.
#
# Once the filters are extracted from the Image, these filters are small sections of the image which will be having different features.
# Number of filters used on the input should created the same number amount of feature maps.
#
# When we process the image, we apply filters which each generates an output that we call feature map. If k-features map is created, we have feature maps with depth k.
#
# The feature map is the output of one filter applied to the previous layer. A given filter is drawn across the entire previous layer, moved one pixel at a time. Each position results in an activation of the neuron and the output is collected in the feature map. You can see that if the receptive field is moved one pixel from activation to activation, then the field will overlap with the previous activation by (field width - 1) input values.
#
# For instance, In a 32 × 32 image , dragging the 5 × 5 receptive field across the input image data with a stride width of 1 will result in a feature map of 28 × 28 (32–5+1 × 32–5+1) output values or 784 distinct activations per image.

# %% [markdown]
# --> Double click here to respond

# %% [markdown]
# ## 2.4 Gradient-weighted Class Activation Mapping (Grad-CAM) [17 marks]
#
# In this section, we will explore using Gradient-weighted Class Activation Mapping (Grad-CAM) to generate coarse localization maps highlighting the important regions in the test images guiding the model's prediction. We will continue using the pre-trained AlexNet.
#
# #### Preparation
# >It is recommended to first read the relevant paper [Grad-CAM: Visual Explanations from Deep Networks via Gradient-based Localization](https://arxiv.org/abs/1610.02391), and refer to relevant course material.
#
# #### The AlexNet class
#
# >To implement Grad-CAM, we need to edit the AlexNet ```module``` class itself, so instead of loading the AlexNet model from ```torch.hub``` as we did above, we will use the official PyTorch AlexNet class code ([taken from here](https://pytorch.org/vision/stable/_modules/torchvision/models/alexnet.html)). In addition to the class definition, there is also a function below called ```alexnet()``` which allows you to specify whether you want the pretrained version or not, and if so, loads the weights.
#
# #### The hook
#
# >[Hooks](https://pytorch.org/tutorials/beginner/former_torchies/nnft_tutorial.html#forward-and-backward-function-hooks) in PyTorch are functions which can be registered, or attached, to a ```Module``` or ```Tensor```. Hooks can be *forward* hooks or *backward* hooks; forward hooks are called with ```forward()``` and backward hooks with ```backward()```. In the model below, we register a forward hook that saves the **gradients of the activations** to the Tensor output of ```model.features```. The gradients are saved to a class variable so we can easily access them.
#
# Carefully read the code block below. You do not need to add anything to the model.

# %%
# defining where to load the pre-trained weights from
model_urls = {
    'alexnet': 'https://download.pytorch.org/models/alexnet-owt-7be5be79.pth',
}

# the class definition
class AlexNet(nn.Module):

    def __init__(self, num_classes=1000):
        super(AlexNet, self).__init__()
        
        # a placeholder for storing the gradients
        self.gradients = None
        
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )
        
    # the hook for the gradients of the activations
    def activations_hook(self, grad):
        # stores the gradients of the hook's tensor to our placeholder variable
        self.gradients = grad

    # a method for extracting the activations of the last conv layer only (when we're 
    # not interested in a full forward pass)
    def get_activations(self, x):
        return self.features(x)
    
    def forward(self, x):
        x = self.features(x)
        
        # we register the hook here to save the gradients of the last convolutional
        # layer outputs
        hook = x.register_hook(self.activations_hook)
        
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x


def alexnet(pretrained=False, progress=True, **kwargs) -> AlexNet:
    """AlexNet model architecture from the
    `"One weird trick..." <https://arxiv.org/abs/1404.5997>`_ paper.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    model = AlexNet(**kwargs)
    if pretrained:
        state_dict = load_state_dict_from_url(model_urls['alexnet'],
                                              progress=progress)
        model.load_state_dict(state_dict)
    return model

# %%
model = alexnet(pretrained=True)

# %%
# pass our test image through our new model with the hook
output = model(im.unsqueeze(0))

# save the predicted class
_, pred_cls = output.max(dim=1, keepdim=True)

# %% [markdown]
# Examine and understand the values stored in ```output``` and ```pred_cls```. What does AlexNet classify the test image as?

# %%
print(output.shape)
print(pred_cls)
# Out:
# torch.Size([1, 1000])
# tensor([[671]])

# %% [markdown]
# ### 2.4.1 Generate Grad-CAM heatmaps [8 marks]
#
# With the hooks in place, now implement the code to generate Grad-CAM heatmaps, by following the guiding comments in the code block below.

# %%
def generate_heatmap(output, class_id, model, image):
    
    # 1. compute the gradient of the score for the predicted class (logit)
    # with respect to the feature map activations of the last convolutional layer
    # Hint: calling .backward() on a Tensor computes its gradients
    # TO COMPLETE
    output[:,-1].backward()
    
    # 2. get the gradients from the model placeholder variable
    # TO COMPLETE
    gradients = model.gradients
    assert list(gradients.shape) == [1, 256, 7, 7]
    
    # pool the gradients across the channels
    pooled_gradients = torch.mean(gradients, dim=[0, 2, 3])
    assert list(pooled_gradients.shape) == [256]
    
    # 3. get the activations of the last convolutional layer
    # TO COMPLETE  
    activations = model.get_activations(image).detach()
    assert list(activations.shape) == [1, 256, 7, 7]
    
    # 4. weight (multiply) the channels (dim=1 of activations) by the corresponding
    # gradients (pooled_gradients)
    # TO COMPLETE
    for i in range(256):
      activations[:, i, :, :] *= pooled_gradients[i]
    # average the channels of the activations and squeeze out the extra dimension
    heatmap = torch.mean(activations, dim=1).squeeze()
    assert list(heatmap.shape) == [7, 7]
    
    # 5. apply a ReLU to the linear combination of maps because we are only 
    # interested in the features that have a positive influence on the class of 
    # interest, i.e. pixels whose intensity should be increased in order to increase y
    # Hint: you can use np.maximum() and torch.max() to perform ReLU if you prefer.
    
    # TO COMPLETE
    heatmap = np.maximum(heatmap, 0)

    # normalize the heatmap
    heatmap /= torch.max(heatmap)

    return heatmap

# %%
heatmap = generate_heatmap(output, pred_cls, model, im.unsqueeze(0))

# %% [markdown]
# Check the dimensions of ```heatmap```. Do they make sense?

# %%
heatmap.shape #yes
# TO COMPLETE
plt.matshow(heatmap.squeeze())
heatmap.shape
# Out:
# torch.Size([7, 7])

# %% [markdown]
# ### 2.4.2 Display heatmaps [4 marks]
#
# Display ```heatmap``` as a coloured heatmap super-imposed onto the original image. To get results as shown in the paper, we recommend the following steps:
#
# 1. Resize the heatmap to match the size of the image.
# 2. Rescale the image to a 0-255 integer range.
# 3. Apply a colormap to the heatmap using ```cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)```.
# 4. Multiply all values of heatmap by 0.4 to reduce colour saturation.
# 5. Superimpose the heatmap onto the original image (Note: please perform cv2's addition - addition of two cv2 images, not numpy addition. See [here](https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_core/py_image_arithmetics/py_image_arithmetics.html#:~:text=addWeighted()%20etc.-,Image%20Addition,OpenCV%20addition%20and%20Numpy%20addition.) for explanation.)
# 6. Normalize the image between 0-255 again.
# 7. Display the resulting image.

# %%
# TO COMPLETE
def display_heatmap(heatmap,image):
#1
  (w, h) = (image.shape[0], image.shape[1])
  heatmap = cv2.resize(heatmap.numpy(), (w, h))
  
#2
  
  numer = heatmap - np.min(heatmap)
  denom = (heatmap.max() - heatmap.min()) + 1e-8
  heatmap_normalized = numer / denom
  heatmap_normalized = (heatmap_normalized * 255).astype("uint8")

  
#3
  heatmap_normalized = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)
#4
  heatmap_normalized=heatmap_normalized * 0.4
#5
  weighted_image= cv2.addWeighted(heatmap_normalized, 0.7, image, 0.3, 0)
#6
  numer = weighted_image - np.min(weighted_image)
  denom = (weighted_image.max() - weighted_image.min()) + 1e-8
  final_image = numer / denom
  final_image = (final_image * 255).astype("uint8")

  return final_image


  
image = cv2.imread('man_bike.JPEG')
image=cv2.resize(image,(256,256))
image = np.asarray(image, np.float64)

display=display_heatmap(heatmap,image)
plt.matshow(display[:, :, ::-1])

# %% [markdown]
# Show the heatmap for class ```'seashore, coast, seacoast, sea-coast'``` (```class_id = 978```), super-imposed onto the original image.

# %%
# TO COMPLETE

# %% [markdown]
# ### 2.4.3 Failure analysis using Grad-CAM [5 marks]
#
# Find an image (online, or from ImageNet or another dataset) which AlexNet classifies *incorrectly*. Display the image below, and show the model's predicted class. Then, generate the Grad-CAM heatmap and display it super-imposed onto the image.

# %%
# TO COMPLETE

swimming=Image.open('grass.jpg')

# ImageNet normalisation values, to apply to the image transform
norm_mean = [0.485, 0.456, 0.406]
norm_std = [0.229, 0.224, 0.225]

data_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize(norm_mean, norm_std),
    ])

swimming = data_transform(swimming)
mod = alexnet(pretrained=True)

# pass our test image through our new model with the hook
output = mod(swimming.unsqueeze(0))

# save the predicted class
_, pred_cls = output.max(dim=1, keepdim=True)
print(pred_cls) # tensor([[291]])
percentage = torch.nn.functional.softmax(output, dim=1)[0] * 100  
 
# ggenerate heatmap
heatmap = generate_heatmap(output, pred_cls, mod, swimming.unsqueeze(0))
swimming=cv2.imread('grass.jpg')
# im2.shape (375, 500, 3) transforms.Resize(256) -> (3, 256, 256)
swimming=cv2.resize(swimming,(256,256))
swimming = np.asarray(swimming, np.float64)
show_result = display_heatmap(heatmap, swimming)
plt.matshow(show_result[:, :, ::-1])
# Out:
# tensor([[522]])

# %% [markdown]
# Briefly describe what explanation the Grad-CAM heatmap provides about why the model has failed to correctly classify your test image.

# %% [markdown]
# We have tken grass image to classify in alex net.
# Prediction we got is 'croquet ball'(522).
#
# For the heat map we can say that it could not found any major features from the image, we got only one brigthly focused area which does not provide any major information to classify the image .
#
# As we use croquet ball in grass fileds we could have got the above result.
#
#
# --> Double click to respond here

# %% [markdown]
# ### 3 Overall quality [2 marks]
#
# Marks awarded for overall degree of code readibility and omission of unnecessary messy outupts (for example, please avoid printed losses for every batch of a long training process, large numpy arrays, etc.) throughout the work.

# %% [markdown]
# **Please refer to the submission section at the top of this notebook to prepare your submission.**
